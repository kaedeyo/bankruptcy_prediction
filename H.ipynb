# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import os

# %% [markdown]
# # DATA IMPORT

# %% [markdown]
# IMPORT TEXT FILES

# %%
# TRAINING SET
#Bankrupt_risk
bankrupted_risk_reports = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/risk_info/bankrupted/trainB')
bankrupted_risk_reports = [file for file in bankrupted_risk_reports]

bankrupted_risk_file = []
for report in range(0, len(bankrupted_risk_reports)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/risk_info/bankrupted/trainB/{bankrupted_risk_reports[report]}", encoding="utf8") as file:
        risk_filesB = file.read()
        bankrupted_risk_file.append(risk_filesB)

        
#Bankrupt_perfo
bankrupted_perfo_reports = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/performance/bankrupted/trainB')
bankrupted_perfo_reports = [file for file in bankrupted_perfo_reports]

bankrupted_perfo_file = []
for report in range(0, len(bankrupted_perfo_reports)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/performance/bankrupted/trainB/{bankrupted_perfo_reports[report]}", encoding="utf8") as file:
        perfo_filesB = file.read()
        bankrupted_perfo_file.append(perfo_filesB)


#Bankrupt_kadai
bankrupted_kadai_reports = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/kadai/bankrupted/trainB')
bankrupted_kadai_reports = [file for file in bankrupted_kadai_reports]

bankrupted_kadai_file = []
for report in range(0, len(bankrupted_kadai_reports)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/kadai/bankrupted/trainB/{bankrupted_kadai_reports[report]}", encoding="utf8") as file:
        kadai_filesB = file.read()
        bankrupted_kadai_file.append(kadai_filesB)

#Bankrupt_tanshin
bankrupted_tanshin_reports = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/tanshin/bankrupted/trainB')
bankrupted_tanshin_reports = [file for file in bankrupted_tanshin_reports]

bankrupted_file_tanshin = []
for report in range(0, len(bankrupted_tanshin_reports)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/tanshin/bankrupted/trainB/{bankrupted_tanshin_reports[report]}", encoding="utf8") as file:
        filesB_tanshin = file.read()
        bankrupted_file_tanshin.append(filesB_tanshin)


df_bankrupted_risk = pd.DataFrame(bankrupted_risk_file)
df_bankrupted_risk.columns = ['risk']
df_bankrupted_risk['Y'] = 0 #Y=0 means bankrupted

df_bankrupted_perfo = pd.DataFrame(bankrupted_perfo_file)
df_bankrupted_perfo.columns = ['perfo']
df_bankrupted_perfo['Y'] = 0

df_bankrupted_kadai = pd.DataFrame(bankrupted_kadai_file)
df_bankrupted_kadai.columns = ['kadai']
df_bankrupted_kadai['Y'] = 0

df_bankrupted_tanshin = pd.DataFrame(bankrupted_file_tanshin)
df_bankrupted_tanshin.columns = ['tanshin']
df_bankrupted_tanshin['Y'] = 0 


#Nonbankrupt_risk
nonbankrupted_risk_reports = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/risk_info/nonbankrupted/trainNB')
nonbankrupted_risk_reports = [file for file in nonbankrupted_risk_reports]

nonbankrupted_risk_file = []
for report in range(0, len(nonbankrupted_risk_reports)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/risk_info/nonbankrupted/trainNB/{nonbankrupted_risk_reports[report]}", encoding="utf8") as file:
        risk_filesNB = file.read()
        nonbankrupted_risk_file.append(risk_filesNB)

        
#Nonbankrupt_perfo
nonbankrupted_perfo_reports = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/performance/nonbankrupted/trainNB')
nonbankrupted_perfo_reports = [file for file in nonbankrupted_perfo_reports]

nonbankrupted_perfo_file = []
for report in range(0, len(nonbankrupted_perfo_reports)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/performance/nonbankrupted/trainNB/{nonbankrupted_perfo_reports[report]}", encoding="utf8") as file:
        perfo_filesNB = file.read()
        nonbankrupted_perfo_file.append(perfo_filesNB)
        

#Nonbankrupt_kadai
nonbankrupted_kadai_reports = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/kadai/nonbankrupted/trainNB')
nonbankrupted_kadai_reports = [file for file in nonbankrupted_kadai_reports]

nonbankrupted_kadai_file = []
for report in range(0, len(nonbankrupted_kadai_reports)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/kadai/nonbankrupted/trainNB/{nonbankrupted_kadai_reports[report]}", encoding="utf8") as file:
        kadai_filesNB = file.read()
        nonbankrupted_kadai_file.append(kadai_filesNB)

#Nonbankrupt__tanshin
nonbankrupted_tanshin_reports = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/tanshin/nonbankrupted/trainNB')
nonbankrupted_tanshin_reports = [file for file in nonbankrupted_tanshin_reports]

nonbankrupted_file_tanshin = []
for report in range(0, len(nonbankrupted_tanshin_reports)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/tanshin/nonbankrupted/trainNB/{nonbankrupted_tanshin_reports[report]}", encoding="utf8") as file:
        filesNB_tanshin = file.read()
        nonbankrupted_file_tanshin.append(filesNB_tanshin) 
        
df_nonbankrupted_risk = pd.DataFrame(nonbankrupted_risk_file)
df_nonbankrupted_risk.columns = ['risk']
df_nonbankrupted_risk['Y'] = 1


df_nonbankrupted_perfo = pd.DataFrame(nonbankrupted_perfo_file)
df_nonbankrupted_perfo.columns = ['perfo']
df_nonbankrupted_perfo['Y'] = 1


df_nonbankrupted_kadai = pd.DataFrame(nonbankrupted_kadai_file)
df_nonbankrupted_kadai.columns = ['kadai']
df_nonbankrupted_kadai['Y'] = 1

df_nonbankrupted_tanshin = pd.DataFrame(nonbankrupted_file_tanshin)
df_nonbankrupted_tanshin.columns = ['tanshin']
df_nonbankrupted_tanshin['Y'] = 1


# concatenated_train
df_risk_train = [df_bankrupted_risk,df_nonbankrupted_risk]
df_risk_train = pd.concat(df_risk_train, ignore_index=True)
# print(df_risk_train)

df_perfo_train = [df_bankrupted_perfo,df_nonbankrupted_perfo]
df_perfo_train = pd.concat(df_perfo_train, ignore_index=True)
# print(df_perfo_train)

df_kadai_train = [df_bankrupted_kadai,df_nonbankrupted_kadai]
df_kadai_train = pd.concat(df_kadai_train, ignore_index=True)
# print(df_kadai_train)

concatenated_tanshin_train = [df_bankrupted_tanshin, df_nonbankrupted_tanshin]
df_tanshin_train = pd.concat(concatenated_tanshin_train, ignore_index= True)
# print(df_tanshin_train)

# %%
# VALIDATION SET
#Bankrupt_risk
bankrupted_risk_reports_val = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/risk_info/bankrupted/valB')
bankrupted_risk_reports_val = [file for file in bankrupted_risk_reports_val]

bankrupted_risk_file_val = []
for report in range(0, len(bankrupted_risk_reports_val)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/risk_info/bankrupted/valB/{bankrupted_risk_reports_val[report]}", encoding="utf8") as file:
        risk_filesB_val = file.read()
        bankrupted_risk_file_val.append(risk_filesB_val)

        
#Bankrupt_perfo
bankrupted_perfo_reports_val = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/performance/bankrupted/valB')
bankrupted_perfo_reports_val = [file for file in bankrupted_perfo_reports_val]

bankrupted_perfo_file_val = []
for report in range(0, len(bankrupted_perfo_reports_val)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/performance/bankrupted/valB/{bankrupted_perfo_reports_val[report]}", encoding="utf8") as file:
        perfo_filesB_val = file.read()
        bankrupted_perfo_file_val.append(perfo_filesB_val)


#Bankrupt_kadai
bankrupted_kadai_reports_val = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/kadai/bankrupted/valB')
bankrupted_kadai_reports_val = [file for file in bankrupted_kadai_reports_val]

bankrupted_kadai_file_val = []
for report in range(0, len(bankrupted_kadai_reports_val)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/kadai/bankrupted/valB/{bankrupted_kadai_reports_val[report]}", encoding="utf8") as file:
        kadai_filesB_val = file.read()
        bankrupted_kadai_file_val.append(kadai_filesB_val)        

        
#Bankrupt_tanshin
bankrupted_tanshin_reports_val = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/tanshin/bankrupted/valB')
bankrupted_tanshin_reports_val = [file for file in bankrupted_tanshin_reports_val]

bankrupted_file_tanshin_val = []
for report in range(0, len(bankrupted_tanshin_reports_val)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/tanshin/bankrupted/valB/{bankrupted_tanshin_reports_val[report]}", encoding="utf8") as file:
        filesB_tanshin_val = file.read()
        bankrupted_file_tanshin_val.append(filesB_tanshin_val)       
        
df_bankrupted_risk_val = pd.DataFrame(bankrupted_risk_file_val)
df_bankrupted_risk_val.columns = ['risk']
df_bankrupted_risk_val['Y'] = 0 #Y=0 means bankrupted


df_bankrupted_perfo_val = pd.DataFrame(bankrupted_perfo_file_val)
df_bankrupted_perfo_val.columns = ['perfo']
df_bankrupted_perfo_val['Y'] = 0

df_bankrupted_kadai_val = pd.DataFrame(bankrupted_kadai_file_val)
df_bankrupted_kadai_val.columns = ['kadai']
df_bankrupted_kadai_val['Y'] = 0

df_bankrupted_tanshin_val = pd.DataFrame(bankrupted_file_tanshin_val)
df_bankrupted_tanshin_val.columns = ['tanshin']
df_bankrupted_tanshin_val['Y'] = 0


#Nonbankrupt_risk
nonbankrupted_risk_reports_val = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/risk_info/nonbankrupted/valNB')
nonbankrupted_risk_reports_val = [file for file in nonbankrupted_risk_reports_val]

nonbankrupted_risk_file_val = []
for report in range(0, len(nonbankrupted_risk_reports_val)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/risk_info/nonbankrupted/valNB/{nonbankrupted_risk_reports_val[report]}", encoding="utf8") as file:
        risk_filesNB_val = file.read()
        nonbankrupted_risk_file_val.append(risk_filesNB_val)

        
#Nonbankrupt_perfo
nonbankrupted_perfo_reports_val = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/performance/nonbankrupted/valNB')
nonbankrupted_perfo_reports_val = [file for file in nonbankrupted_perfo_reports_val]

nonbankrupted_perfo_file_val = []
for report in range(0, len(nonbankrupted_perfo_reports_val)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/performance/nonbankrupted/valNB/{nonbankrupted_perfo_reports_val[report]}", encoding="utf8") as file:
        perfo_filesNB_val = file.read()
        nonbankrupted_perfo_file_val.append(perfo_filesNB_val)

#Nonbankrupt_kadai
nonbankrupted_kadai_reports_val = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/kadai/nonbankrupted/valNB')
nonbankrupted_kadai_reports_val = [file for file in nonbankrupted_kadai_reports_val]

nonbankrupted_kadai_file_val = []
for report in range(0, len(nonbankrupted_kadai_reports_val)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/kadai/nonbankrupted/valNB/{nonbankrupted_kadai_reports_val[report]}", encoding="utf8") as file:
        kadai_filesNB_val = file.read()
        nonbankrupted_kadai_file_val.append(kadai_filesNB_val)
        
#Nonbankrupt_tanshin
nonbankrupted_tanshin_reports_val = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/tanshin/nonbankrupted/valNB')
nonbankrupted_tanshin_reports_val = [file for file in nonbankrupted_tanshin_reports_val]

nonbankrupted_file_tanshin_val = []
for report in range(0, len(nonbankrupted_tanshin_reports_val)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/tanshin/nonbankrupted/valNB/{nonbankrupted_tanshin_reports_val[report]}", encoding="utf8") as file:
        filesNB_tanshin_val = file.read()
        nonbankrupted_file_tanshin_val.append(filesNB_tanshin_val)
        
df_nonbankrupted_risk_val = pd.DataFrame(nonbankrupted_risk_file_val)
df_nonbankrupted_risk_val.columns = ['risk']
df_nonbankrupted_risk_val['Y'] = 1

df_nonbankrupted_perfo_val = pd.DataFrame(nonbankrupted_perfo_file_val)
df_nonbankrupted_perfo_val.columns = ['perfo']
df_nonbankrupted_perfo_val['Y'] = 1

df_nonbankrupted_kadai_val = pd.DataFrame(nonbankrupted_kadai_file_val)
df_nonbankrupted_kadai_val.columns = ['kadai']
df_nonbankrupted_kadai_val['Y'] = 1

df_nonbankrupted_tanshin_val = pd.DataFrame(nonbankrupted_file_tanshin_val)
df_nonbankrupted_tanshin_val.columns = ['tanshin']
df_nonbankrupted_tanshin_val['Y'] = 1 


# concatenated_val
df_risk_val = [df_bankrupted_risk_val,df_nonbankrupted_risk_val]
df_risk_val = pd.concat(df_risk_val, ignore_index=True)
# print(df_risk_val)

df_perfo_val = [df_bankrupted_perfo_val,df_nonbankrupted_perfo_val]
df_perfo_val = pd.concat(df_perfo_val, ignore_index=True)
# print(df_perfo_val)

df_kadai_val = [df_bankrupted_kadai_val,df_nonbankrupted_kadai_val]
df_kadai_val = pd.concat(df_kadai_val, ignore_index=True)
# print(df_kadai_val)

concatenated_tanshin_val = [df_bankrupted_tanshin_val, df_nonbankrupted_tanshin_val]
df_tanshin_val = pd.concat(concatenated_tanshin_val, ignore_index=True)
# print(df_tanshin_val)

# %%
# TEST SET

#Bankrupt_risk (test data)
bankrupted_risk_reports_test = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/risk_info/bankrupted/testB')

bankrupted_risk_file_test = []
for report in range(0, len(bankrupted_risk_reports_test)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/risk_info/bankrupted/testB/{bankrupted_risk_reports_test[report]}", encoding="utf8") as file:
        filesB_test = file.read()
        bankrupted_risk_file_test.append(filesB_test)


#Bankrupt_perfo(test data)
bankrupted_perfo_reports_test = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/performance/bankrupted/testB')
bankrupted_perfo_reports_test = [file for file in bankrupted_perfo_reports_test]

bankrupted_perfo_file_test = []
for report in range(0, len(bankrupted_perfo_reports_test)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/performance/bankrupted/testB/{bankrupted_perfo_reports_test[report]}", encoding="utf8") as file:
        perfo_filesB_test = file.read()
        bankrupted_perfo_file_test.append(perfo_filesB_test)


#Bankrupt_kadai(test data)
bankrupted_kadai_reports_test = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/kadai/bankrupted/testB')
bankrupted_kadai_reports_test = [file for file in bankrupted_kadai_reports_test]

bankrupted_kadai_file_test = []
for report in range(0, len(bankrupted_kadai_reports_test)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/kadai/bankrupted/testB/{bankrupted_kadai_reports_test[report]}", encoding="utf8") as file:
        kadai_filesB_test = file.read()
        bankrupted_kadai_file_test.append(kadai_filesB_test)        

#Bankrupt_tanshin(test data)
bankrupted_tanshin_reports_test = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/tanshin/bankrupted/testB')
bankrupted_tanshin_reports_test = [file for file in bankrupted_tanshin_reports_test]

bankrupted_tanshin_file_test = []
for report in range(0, len(bankrupted_tanshin_reports_test)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/tanshin/bankrupted/testB/{bankrupted_tanshin_reports_test[report]}", encoding="utf8") as file:
        tanshin_filesB_test = file.read()
        bankrupted_tanshin_file_test.append(tanshin_filesB_test)
        
df_bankrupted_risk_test = pd.DataFrame(bankrupted_risk_file_test)
df_bankrupted_risk_test.columns = ['risk']
df_bankrupted_risk_test['Y'] = 0 #Y=0 means bankrupted


df_bankrupted_perfo_test = pd.DataFrame(bankrupted_perfo_file_test)
df_bankrupted_perfo_test.columns = ['perfo']
df_bankrupted_perfo_test['Y'] = 0

df_bankrupted_kadai_test = pd.DataFrame(bankrupted_kadai_file_test)
df_bankrupted_kadai_test.columns = ['kadai']
df_bankrupted_kadai_test['Y'] = 0

df_bankrupted_tanshin_test = pd.DataFrame(bankrupted_tanshin_file_test)
df_bankrupted_tanshin_test.columns = ['tanshin']
df_bankrupted_tanshin_test['Y'] = 0

#Nonbankrupt_risk (test data)
nonbankrupted_risk_reports_test = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/risk_info/nonbankrupted/testNB')
nonbankrupted_risk_reports_test = [file for file in nonbankrupted_risk_reports_test]

nonbankrupted_risk_file_test = []
for report in range(0, len(nonbankrupted_risk_reports_test)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/risk_info/nonbankrupted/testNB/{nonbankrupted_risk_reports_test[report]}", encoding="utf8") as file:
        risk_filesNB_test = file.read()
        nonbankrupted_risk_file_test.append(risk_filesNB_test)
        
#Nonbankrupt_perfo(test data)
nonbankrupted_perfo_reports_test = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/performance/nonbankrupted/testNB')
nonbankrupted_perfo_reports_test = [file for file in nonbankrupted_perfo_reports_test]

nonbankrupted_perfo_file_test = []
for report in range(0, len(nonbankrupted_perfo_reports_test)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/performance/nonbankrupted/testNB/{nonbankrupted_perfo_reports_test[report]}", encoding="utf8") as file:
        perfo_filesNB_test = file.read()
        nonbankrupted_perfo_file_test.append(perfo_filesNB_test)

#Nonbankrupt_kadai(test data)
nonbankrupted_kadai_reports_test = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/kadai/nonbankrupted/testNB')
nonbankrupted_kadai_reports_test = [file for file in nonbankrupted_kadai_reports_test]

nonbankrupted_kadai_file_test = []
for report in range(0, len(nonbankrupted_kadai_reports_test)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/kadai/nonbankrupted/testNB/{nonbankrupted_kadai_reports_test[report]}", encoding="utf8") as file:
        kadai_filesNB_test = file.read()
        nonbankrupted_kadai_file_test.append(kadai_filesNB_test)        
        
#Nonbankrupt_tanshin(test data)
nonbankrupted_tanshin_reports_test = os.listdir('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/tanshin/nonbankrupted/testNB')
nonbankrupted_tanshin_reports_test = [file for file in nonbankrupted_tanshin_reports_test]

nonbankrupted_tanshin_file_test = []
for report in range(0, len(nonbankrupted_tanshin_reports_test)):
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/tanshin/nonbankrupted/testNB/{nonbankrupted_tanshin_reports_test[report]}", encoding="utf8") as file:
        tanshin_filesNB_test = file.read()
        nonbankrupted_tanshin_file_test.append(tanshin_filesNB_test)

df_nonbankrupted_risk_test = pd.DataFrame(nonbankrupted_risk_file_test)
df_nonbankrupted_risk_test.columns = ['risk']
df_nonbankrupted_risk_test['Y'] = 1


df_nonbankrupted_perfo_test = pd.DataFrame(nonbankrupted_perfo_file_test)
df_nonbankrupted_perfo_test.columns = ['perfo']
df_nonbankrupted_perfo_test['Y'] = 1

df_nonbankrupted_kadai_test = pd.DataFrame(nonbankrupted_kadai_file_test)
df_nonbankrupted_kadai_test.columns = ['kadai']
df_nonbankrupted_kadai_test['Y'] = 1

df_nonbankrupted_tanshin_test = pd.DataFrame(nonbankrupted_tanshin_file_test)
df_nonbankrupted_tanshin_test.columns = ['tanshin']
df_nonbankrupted_tanshin_test['Y'] = 1

# concatenated_test
df_risk_test = [df_bankrupted_risk_test,df_nonbankrupted_risk_test]
df_risk_test = pd.concat(df_risk_test, ignore_index=True)
# print(df_risk_test)

df_perfo_test = [df_bankrupted_perfo_test,df_nonbankrupted_perfo_test]
df_perfo_test = pd.concat(df_perfo_test, ignore_index=True)
# print(df_perfo_test)

df_kadai_test = [df_bankrupted_kadai_test,df_nonbankrupted_kadai_test]
df_kadai_test = pd.concat(df_kadai_test, ignore_index=True)
# print(df_kadai_test)

df_tanshin_test = [df_bankrupted_tanshin_test,df_nonbankrupted_tanshin_test]
df_tanshin_test = pd.concat(df_tanshin_test, ignore_index=True)
# print(df_tanshin_test)

# %% [markdown]
# IMPORT RATIO DATASET

# %%
# TRAINING SET

traindata = pd.read_csv('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/ratios/train_ratio.csv')
# print('TRAINING DATASET \n:', traindata.describe().transpose())
X_train_ratio = traindata.drop('Y', axis=1)
y_train_ratio = traindata['Y']
# print(sns.countplot(x = 'Y', data=traindata))

# VALIDATION SET

valdata = pd.read_csv('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/ratios/val_ratio.csv')
# print('VALIDATION DATASET \n:', valdata.describe().transpose())
X_val_ratio = valdata.drop('Y', axis=1)
y_val_ratio = valdata['Y']

# TEST SET

testdata = pd.read_csv('C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/DATAFRAMES/ratios/test_ratio.csv')
# print('TEST DATASET \n:', testdata.describe().transpose())
# print('TEST DATASET \n:', testdata)
X_test_ratio = testdata.drop('Y', axis=1)
y_test_ratio = testdata['Y']

# %% [markdown]
# COMBINE BOTH RATIOS + TEXT DATA

# %%
# ADD THE A NEW COLUMN FOR TEXT FILE

X_train_ratio['risk'] = df_risk_train['risk']
X_train_ratio['perfo'] = df_perfo_train['perfo']
X_train_ratio['kadai'] = df_kadai_train['kadai']
X_train_ratio['tanshin'] = df_tanshin_train['tanshin']

X_val_ratio['risk'] = df_risk_val['risk']
X_val_ratio['perfo'] = df_perfo_val['perfo']
X_val_ratio['kadai'] = df_kadai_val['kadai']
X_val_ratio['tanshin'] = df_tanshin_val['tanshin']

X_test_ratio['risk'] = df_risk_test.drop('Y', axis=1)
X_test_ratio['perfo'] = df_perfo_test.drop('Y', axis=1)
X_test_ratio['kadai'] = df_kadai_test.drop('Y', axis=1)
X_test_ratio['tanshin'] = df_tanshin_test.drop('Y', axis=1)

# CREATE NEW DATAFRAME FOR COMBINED DATA

X_train_both = X_train_ratio
X_val_both = X_val_ratio
X_test_both = X_test_ratio

y_train_both = y_train_ratio
y_val_both = y_val_ratio
y_test_both = y_test_ratio

# %%
X_train_ratio
# Out:
#        X19    X20   X29     X47    X51    X54     X59     X62      X63    X64  \
# 0   -56.50 -12.14  4.35 -143.28   0.00  -3.17  217.91   48.72   173.50  36.20
# 1     4.33   1.34  1.36    1.67   0.00  81.72   51.61  123.96  1288.35   7.12
# 2  -220.42   0.81  1.81  -23.60   0.00  -7.36   56.14  206.41   844.44  10.64
# 3     9.13   2.01  0.18    2.24   0.00   8.37  132.09   30.43   204.28  32.86
# 4    19.44   8.63  1.91   18.37   0.00  10.39   39.96   14.71   283.68  26.06
# ..     ...    ...   ...     ...    ...    ...     ...     ...      ...    ...
# 87   -1.10   0.00  1.06    4.42  20.61  23.69   46.37  104.47   445.89  18.27
# 88    5.82   7.83  0.00   13.00   0.84   0.00  192.25   53.71    49.12  67.05
# 89   25.94  30.94  0.00    7.39   0.00   0.07  309.99   15.18    42.85  69.84
# 90    2.15   3.50  0.79   30.26  36.38   2.63   95.92   96.99    66.94  58.92
# 91   14.57   8.28  0.23   16.63   3.25   5.68  122.27   79.58   241.40  27.25
#
#     ...     X74    X76     X77    X79      X80    X84  \
# 0   ...  228.53 -26.80  -44.75   0.00   308.94  -4.64
# 1   ... -103.33  -4.49 -838.37 -12.80 -1495.54   3.03
# 2   ...  914.70 -24.20   12.38 -21.79 -2198.07  -2.33
# 3   ... -111.94  -8.85   10.06  -0.34  -114.86 -10.88
# 4   ...   61.80  77.84   76.70   2.81    64.88 -44.19
# ..  ...     ...    ...     ...    ...      ...    ...
# 87  ... -106.65  -1.26  -28.94   5.42   -71.98  -7.91
# 88  ...  -48.63 -14.17    4.40  -6.25   -21.04 -28.06
# 89  ...    8.13  13.99   16.96  11.30     8.37  55.29
# 90  ...   -1.32   4.77    1.29  -0.14     1.70  67.83
# 91  ...   -0.13   1.56   21.28   6.03     2.56  28.75
#
#                                                  risk  \
# 0   当社グループの経営成績、株価及び財務状況等に重要な影響を及ぼす可能性のある事業等のリスクには...
# 1   有価証券報告書に記載した事業の状況、経理の状況等に関する事項のうち、投資者の判断に重要な影響...
# 2   当グループの経営成績、財務状況等に影響を及ぼす可能性のあるリスクには次のようなものがある。た...
# 3   有価証券報告書に記載した事業の状況、経理の状況等に関する事項のうち、投資者の判断に重要な影響...
# 4   （１）法的規制のリスク\n　当社グループの属する建設、不動産業界は、建設業法、建築基準法、都...
# ..                                                ...
# 87  有価証券報告書に記載した事業の状況、経理の状況等に関する事項のうち、投資者の判断に重要な影響...
# 88  有価証券報告書に記載した事業の状況、経理の状況等に関する事項のうち、投資者の判断に重要な影響...
# 89  以下において、当社グループの事業展開上のリスク要因となる可能性があると考えられる主な事項を記...
# 90  　有価証券報告書に記載した事業の状況、経理の状況等に関する事項のうち、投資者の判断に重要な影...
# 91  当社グループの経営成績及び財政状態は、今後起こりうる様々な要因により影響を受ける可能性があり...
#
#                                                 perfo  \
# 0   (1) 業績\n\n当連結会計年度における世界経済は全体としては緩やかに回復しました。米国は...
# 1   (1) 業績\n　当連結会計年度におけるわが国経済は、厳しい雇用情勢が続く中にあっても、個人...
# 2   (1) 業績\n当連結会計年度におけるわが国経済は、民間設備投資、株価の上昇等に回復の兆しが...
# 3   (1) 業績\n当連結会計年度におけるわが国経済は、米国の景気減速あるいは金利上昇懸念等の先...
# 4   (1）業績\n　当連結会計年度におけるわが国経済は、景気拡大基調を維持し、原油等資源価格高止...
# ..                                                ...
# 87  (1）業績\n\n　当連結会計年度（平成20年４月１日～平成21年３月31日（以下「当期」と...
# 88  (1）業績\n\n　当連結会計年度における我が国経済は、世界的な金融不安に端を発した、企業業...
# 89  (1) 業績\n当連結会計年度におけるわが国経済は、平成23年３月に発生した東日本大震災の影...
# 90  (1）業績\n　当連結会計年度におけるわが国経済は、個人消費がおおむね横ばいで推移する中、企...
# 91  (1) 業績\n①　業績の概況\n\n当連結会計年度のわが国経済は、海外経済の拡大を背景とし...
#
#                                                 kadai  \
# 0   文中の将来に関する事項は、当連結会計年度末現在において当社グループが判断したものであります。...
# 1   今後の経済の見通しについては、世界経済の回復による企業業績の改善を背景に、引き続き回復傾向が...
# 2   今後の見通しについては、雇用情勢・公共投資は依然厳しく、デフレからの脱却や企業収益・民間設備...
# 3   次期の見通しについては、景気は引き続き回復基調で推移するものと思われるが、先行きを懸念する材...
# 4   当社は、建築請負を基盤事業としつつ、社会情勢、経済環境の変化に柔軟に対応するため、建設事業、...
# ..                                                ...
# 87  (1）経営の基本方針\n\n  当社グループは、「安全は経営の基盤であり、社会への責務である...
# 88  景気の減速が見られ、海外旅行需要が伸び悩む環境下にありますが、従来から確保してきたリピーター...
# 89  当社グループが提供しております国際物流サービスは、ますますグローバル化した国際社会において重...
# 90  (1) 当面の対処すべき課題の内容等\n    当社グループは、本年５月に、新たに平成19年...
# 91  (1) 当面の対処すべき課題の内容\n当社グループが対処すべき課題は、事業の拡大とその内部体...
#
#                                               tanshin
# 0   平成30年３月期の通期連結業績予想につきましては、売上高は当期に比べて39.1%増の21,3...
# 1   通期の見通しにつきましては、世界経済の回復による企業業績の改善を背景に、景気は引き続き回復傾...
# 2   今後の見通しにつきましては、雇用情勢・公共投資は依然厳しく、デフレからの脱却や企業収益・民間...
# 3   次期の見通しにつきましては、景気は引き続き回復基調で推移するものと思われますが、先行きを懸念...
# 4   平成 18 年度の景気は好調な輸出と企業収益に支えられた設備投資の増加、さらに個人消費の堅調...
# ..                                                ...
# 87  今後の経済見通しにつきましては、本年中は、昨年９月以降の世界的な不況が継続するとの見通しから...
# 88  通期の見通しといたしましては、営業収益は68億20百万円（前期比2.8％増）、営業利益は２億...
# 89  次期の見通しにつきましては、復興需要や比較的堅調な中国経済の影響で緩やかに景気の持ち直しが期...
# 90  　わが国経済は、海外経済の拡大を背景に、輸出の増加、企業収益の増加等により、緩やかに回復を続...
# 91  次期の見通しにつきましては、シルバー事業が前期は制度改定の影響の多くが下半期に限定されていま...
#
# [92 rows x 26 columns]

# %%
print('Length of X (train): {} | Length of Y (train): {}'.format(len(X_train_both), len(y_train_both)))
print('Length of X (validation): {} | Length of Y (validation): {}'.format(len(X_val_both), len(y_val_both)))
print('Length of X (test): {} | Length of Y (test): {}'.format(len(X_test_both), len(y_test_both)))
# Out:
# Length of X (train): 92 | Length of Y (train): 92
# Length of X (validation): 20 | Length of Y (validation): 20
# Length of X (test): 25 | Length of Y (test): 25

# %%
# print(X_test_both)
# print(X_train_both['risk'])
# print(X_train_both['perfo'])
# print(X_train_both['kadai'])

# %% [markdown]
# # TEXT PREPROCESSING

# %%
from janome.tokenizer import Tokenizer
from janome.analyzer import Analyzer
from janome.charfilter import *
from janome.tokenfilter import *
import nltk
import re

# %%
def clean_data(risk_report_test):
    """Returns cleaned text data."""
    
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/stop_words.txt", mode="r", encoding="utf8") as file:
        stop_words = file.read()
    
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/stop_words_accounting.txt", mode="r", encoding="utf8") as file:
        stop_words_acc = file.read()
    
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/onaji_risk_vocab.txt", mode="r", encoding="utf8") as file:
        onaji_risk_vocab = file.read()
        
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/onaji_performance_vocab.txt", mode="r", encoding="utf8") as file:
        onaji_performance_vocab = file.read()
    
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/onaji_kadai_vocab.txt", mode="r", encoding="utf8") as file:
        onaji_kadai_vocab = file.read()
    
    with open(f"C:/Users/onjad/OneDrive/Documents/RESEARCH PHD/article 3/CODES/onaji_tanshin_vocab.txt", mode="r", encoding="utf8") as file:
        onaji_tanshin_vocab = file.read()  
    
    char_filters = [UnicodeNormalizeCharFilter(), 
                    RegexReplaceCharFilter(u'キャッシュ・フロー', u'キャッシュフロー')]
    tokenizer = Tokenizer()
    token_filters = [CompoundNounFilter(), 
                     POSStopFilter(['記号','助詞', '数', '数接続', '接続詞','連体詞', '接頭詞', '名詞,数','非自立', '代名詞', '自動詞', '他動詞']), 
                     LowerCaseFilter()]


    a = Analyzer(char_filters=char_filters, tokenizer=tokenizer, token_filters=token_filters)
    
    def filter(text):
        """
        :param text: str
        :rtype : str
        """
       # アルファベットと半角英数と記号と改行とタブを排除
        text = re.sub(r'[a-zA-Z0-9¥"¥.¥,¥@]+', '', text)
        text = re.sub(r'[!"“#$%&()\*\+\-\.,\/:;<=>?@\[\\\]^_`{|}~]', '', text)
        text = re.sub(r'[\n|\r|\t]', '', text)
        
        # 日本語以外の文字を排除
        jp_chartype_tokenizer = nltk.RegexpTokenizer(u'([ぁ-んー]+|[ァ-ンー]+|[\u4e00-\u9FFF]+|[ぁ-んァ-ンー\u4e00-\u9FFF]+)')
        text = ''.join(jp_chartype_tokenizer.tokenize(text))
        
        return text

    nosymbol_test = filter(risk_report_test)
    
    doc = []
    for token in a.analyze(nosymbol_test):
        doc.append(token.surface)
    doc = [x for x in doc if x not in stop_words]
    doc = [x for x in doc if x not in stop_words_acc]
    doc = [x for x in doc if x not in onaji_risk_vocab]
    doc = [x for x in doc if x not in onaji_performance_vocab]
    doc = [x for x in doc if x not in onaji_kadai_vocab]
    doc = [x for x in doc if x not in onaji_tanshin_vocab]
    doc = np.array(doc)
    
    return doc

#     corpus = ' '.join(doc)
#     corpus = [corpus]
    
#     return corpus

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
X_train_both['texts'] = X_train_both[['risk','perfo', 'kadai','tanshin']] .apply(lambda x: ''.join(x), axis=1)
# print(X_train_both['texts'][0])

X_val_both['texts'] = X_val_both[['risk','perfo', 'kadai','tanshin']] .apply(lambda x: ''.join(x), axis=1)
# print(X_val_both['texts'][0])

X_test_both['texts'] = X_test_both[['risk','perfo', 'kadai','tanshin']] .apply(lambda x: ''.join(x), axis=1)
# print(X_test_both['texts'][0])

# %%
df_text_only = pd.concat([X_train_both['texts'], X_val_both['texts'], X_test_both['texts']], ignore_index=True)
print(df_text_only)
# Out:
# 0      当社グループの経営成績、株価及び財務状況等に重要な影響を及ぼす可能性のある事業等のリスクには...
# 1      有価証券報告書に記載した事業の状況、経理の状況等に関する事項のうち、投資者の判断に重要な影響...
# 2      当グループの経営成績、財務状況等に影響を及ぼす可能性のあるリスクには次のようなものがある。た...
# 3      有価証券報告書に記載した事業の状況、経理の状況等に関する事項のうち、投資者の判断に重要な影響...
# 4      （１）法的規制のリスク\n　当社グループの属する建設、不動産業界は、建設業法、建築基準法、都...
#                              ...
# 132    当社及び当社の関係会社（以下「当社グループ」といいます）の経営成績、株価及び財務状況等に影響...
# 133    以下において、当社グループの事業展開上、リスク要因となる可能性があると考えられる主な事項を記...
# 134    当社グループの経営成績及び財政状態などに重要な影響を及ぼす可能性がある事項には、以下のような...
# 135    本書に記載した事業の状況、経理に関する事項のうち、投資家の判断に重要な影響を及ぼす可能性のあ...
# 136    有価証券報告書に記載した事業の状況、経理の状況等に関する事項のうち、投資者の判断に重要な影響...
# Name: texts, Length: 137, dtype: object

# %%
# print(df_text_only[91]) #train 0 a 92
# print(df_text_only[111]) #val 92 a 112
# print(df_text_only[112]) #test 112 a 137

# %%
clean_file_transformer = CountVectorizer(analyzer=clean_data).fit(df_text_only)
# print(clean_file_transformer.get_feature_names())

# %%
print(len(clean_file_transformer.vocabulary_))
# Out:
# 26582

# %%
clean_file_bow = clean_file_transformer.transform(df_text_only)
# print(clean_file_bow)
print('Shape of Sparse Matrix: ', clean_file_bow.shape)
# Out:
# Shape of Sparse Matrix:  (137, 26582)

# %%
transformer_tfidf = TfidfTransformer().fit(clean_file_bow)
clean_file_tfidf = transformer_tfidf.transform(clean_file_bow)

# print(clean_file_tfidf)
print(clean_file_tfidf.shape)
# Out:
# (137, 26582)

# %% [markdown]
# # RATIO PREPROCESSING

# %%
X_train_ratio = X_train_ratio.drop('risk', axis=1)
X_train_ratio = X_train_ratio.drop('perfo', axis=1)
X_train_ratio = X_train_ratio.drop('kadai', axis=1)
X_train_ratio = X_train_ratio.drop('tanshin', axis=1)
X_train_ratio
# Out:
#        X19    X20   X29     X47    X51    X54     X59     X62      X63    X64  \
# 0   -56.50 -12.14  4.35 -143.28   0.00  -3.17  217.91   48.72   173.50  36.20
# 1     4.33   1.34  1.36    1.67   0.00  81.72   51.61  123.96  1288.35   7.12
# 2  -220.42   0.81  1.81  -23.60   0.00  -7.36   56.14  206.41   844.44  10.64
# 3     9.13   2.01  0.18    2.24   0.00   8.37  132.09   30.43   204.28  32.86
# 4    19.44   8.63  1.91   18.37   0.00  10.39   39.96   14.71   283.68  26.06
# ..     ...    ...   ...     ...    ...    ...     ...     ...      ...    ...
# 87   -1.10   0.00  1.06    4.42  20.61  23.69   46.37  104.47   445.89  18.27
# 88    5.82   7.83  0.00   13.00   0.84   0.00  192.25   53.71    49.12  67.05
# 89   25.94  30.94  0.00    7.39   0.00   0.07  309.99   15.18    42.85  69.84
# 90    2.15   3.50  0.79   30.26  36.38   2.63   95.92   96.99    66.94  58.92
# 91   14.57   8.28  0.23   16.63   3.25   5.68  122.27   79.58   241.40  27.25
#
#     ...      X71     X72     X73     X74    X76     X77    X79      X80  \
# 0   ... -1102.48  333.84  257.75  228.53 -26.80  -44.75   0.00   308.94
# 1   ...   111.11  203.17  570.71 -103.33  -4.49 -838.37 -12.80 -1495.54
# 2   ...   -29.03  -50.36  -36.22  914.70 -24.20   12.38 -21.79 -2198.07
# 3   ...     9.69   33.15  295.54 -111.94  -8.85   10.06  -0.34  -114.86
# 4   ...    32.01   42.59   44.35   61.80  77.84   76.70   2.81    64.88
# ..  ...      ...     ...     ...     ...    ...     ...    ...      ...
# 87  ...   -28.34  -91.01  -99.84 -106.65  -1.26  -28.94   5.42   -71.98
# 88  ...   -23.03  -34.88  -34.81  -48.63 -14.17    4.40  -6.25   -21.04
# 89  ...     4.96    6.39    6.09    8.13  13.99   16.96  11.30     8.37
# 90  ...     3.44   40.28   47.57   -1.32   4.77    1.29  -0.14     1.70
# 91  ...     2.07  -13.74  -15.80   -0.13   1.56   21.28   6.03     2.56
#
#       X84                                              texts
# 0   -4.64  当社グループの経営成績、株価及び財務状況等に重要な影響を及ぼす可能性のある事業等のリスクには...
# 1    3.03  有価証券報告書に記載した事業の状況、経理の状況等に関する事項のうち、投資者の判断に重要な影響...
# 2   -2.33  当グループの経営成績、財務状況等に影響を及ぼす可能性のあるリスクには次のようなものがある。た...
# 3  -10.88  有価証券報告書に記載した事業の状況、経理の状況等に関する事項のうち、投資者の判断に重要な影響...
# 4  -44.19  （１）法的規制のリスク\n　当社グループの属する建設、不動産業界は、建設業法、建築基準法、都...
# ..    ...                                                ...
# 87  -7.91  有価証券報告書に記載した事業の状況、経理の状況等に関する事項のうち、投資者の判断に重要な影響...
# 88 -28.06  有価証券報告書に記載した事業の状況、経理の状況等に関する事項のうち、投資者の判断に重要な影響...
# 89  55.29  以下において、当社グループの事業展開上のリスク要因となる可能性があると考えられる主な事項を記...
# 90  67.83  　有価証券報告書に記載した事業の状況、経理の状況等に関する事項のうち、投資者の判断に重要な影...
# 91  28.75  当社グループの経営成績及び財政状態は、今後起こりうる様々な要因により影響を受ける可能性があり...
#
# [92 rows x 23 columns]

# %%
X_val_ratio = X_val_ratio.drop('risk', axis=1)
X_val_ratio = X_val_ratio.drop('perfo', axis=1)
X_val_ratio = X_val_ratio.drop('kadai', axis=1)
X_val_ratio = X_val_ratio.drop('tanshin', axis=1)
# print(X_val_ratio)

X_test_ratio = X_test_ratio.drop('risk', axis=1)
X_test_ratio = X_test_ratio.drop('perfo', axis=1)
X_test_ratio = X_test_ratio.drop('kadai', axis=1)
X_test_ratio = X_test_ratio.drop('tanshin', axis=1)
# print(X_test_ratio)

# %%
# DATA PREPROCESSING

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_ratio = scaler.fit_transform(X_train_ratio.drop('texts', axis=1))
X_val_ratio = scaler.transform(X_val_ratio.drop('texts', axis=1))
X_test_ratio = scaler.transform(X_test_ratio.drop('texts', axis=1))

# %%
# X_test_ratio

# %% [markdown]
# # CLASSIFICATION TASK - NEURAL NETWORK

# %% [markdown]
# DATA SPLIT

# %%
# RATIOS
Xtrain_ratio = pd.DataFrame(X_train_ratio)
Xval_ratio = pd.DataFrame(X_val_ratio)
Xtest_ratio = pd.DataFrame(X_test_ratio)

# rename columns
Xtrain_ratio.columns = ['X19','X20','X29','X47', 'X51', 'X54', 'X59', 'X62','X63','X64','X67', 'X69', 'X70', 'X71','X72', 'X73', 'X74', 'X76','X77', 'X79', 'X80', 'X84']
Xval_ratio.columns = ['X19','X20','X29','X47', 'X51', 'X54', 'X59', 'X62','X63','X64','X67', 'X69', 'X70', 'X71','X72', 'X73', 'X74', 'X76','X77', 'X79', 'X80', 'X84']
Xtest_ratio.columns = ['X19','X20','X29','X47', 'X51', 'X54', 'X59', 'X62','X63','X64','X67', 'X69', 'X70', 'X71','X72', 'X73', 'X74', 'X76','X77', 'X79', 'X80', 'X84']

print(Xtrain_ratio.shape, Xval_ratio.shape, Xtest_ratio.shape)
# Out:
# (92, 22) (20, 22) (25, 22)

# %%
# Xtest_ratio

# %%
# TEXT
X = clean_file_tfidf
X = pd.DataFrame.sparse.from_spmatrix(X)
X_train_text = X[:92]
X_val_text = pd.DataFrame(X[92:112])
X_test_text = pd.DataFrame(X[112:])

# %%
X_val_text.index.delete
X_val_text = X_val_text.reset_index(drop=True)
# X_val_text

# %%
X_test_text.index.delete
X_test_text = X_test_text.reset_index(drop=True)
# X_test_text

# %%
print(X_train_text.shape, X_val_text.shape, X_test_text.shape)
# Out:
# (92, 26582) (20, 26582) (25, 26582)

# %%
# INPUT VALUES X

X_train = pd.concat([Xtrain_ratio, X_train_text], ignore_index=True, axis=1)
X_val = pd.concat([Xval_ratio, X_val_text], ignore_index=True, axis=1)
X_test = pd.concat([Xtest_ratio, X_test_text], ignore_index=True, axis=1)

print(X_train.shape, X_val.shape, X_test.shape)
# Out:
# (92, 26604) (20, 26604) (25, 26604)

# %%
# X_test

# %%
# TARGET VALUE Y

y_train = pd.DataFrame(y_train_ratio)
y_val = pd.DataFrame(y_val_ratio)
y_test = pd.DataFrame(y_test_ratio)

print(y_train.shape, y_val.shape, y_test.shape)
# Out:
# (92, 1) (20, 1) (25, 1)

# %% [markdown]
# NEURAL NETWORK CLASSIFIER

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout

model = Sequential([
    Dense(units=500, activation='relu', input_dim=X_train.shape[1]),
    Dense(units=500, activation='relu'),
    Dense(units=1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# C:\Users\onjad\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\onjad\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\onjad\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\onjad\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\onjad\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\onjad\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\onjad\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\onjad\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\onjad\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\onjad\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\onjad\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\onjad\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From C:\Users\onjad\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\onjad\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 500)               13302500
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 501
# =================================================================
# Total params: 13,553,501
# Trainable params: 13,553,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
# TRAIN MODEL

from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)

model.fit(X_train, y_train, validation_data=(X_val, y_val) , epochs=3000, verbose=2,callbacks=[early_stop])
# Out:
# Train on 92 samples, validate on 20 samples
# Epoch 1/3000
# 92/92 - 10s - loss: 0.6891 - acc: 0.5870 - val_loss: 0.6865 - val_acc: 0.5500
# Epoch 2/3000
# 92/92 - 0s - loss: 0.5736 - acc: 1.0000 - val_loss: 0.6687 - val_acc: 0.7500
# Epoch 3/3000
# 92/92 - 0s - loss: 0.3587 - acc: 1.0000 - val_loss: 0.6346 - val_acc: 0.8000
# Epoch 4/3000
# 92/92 - 0s - loss: 0.1414 - acc: 1.0000 - val_loss: 0.5963 - val_acc: 0.8000
# Epoch 5/3000
# 92/92 - 0s - loss: 0.0333 - acc: 1.0000 - val_loss: 0.5485 - val_acc: 0.8000
# Epoch 6/3000
# 92/92 - 0s - loss: 0.0056 - acc: 1.0000 - val_loss: 0.5124 - val_acc: 0.8000
# Epoch 7/3000
# 92/92 - 0s - loss: 0.0010 - acc: 1.0000 - val_loss: 0.4886 - val_acc: 0.8000
# Epoch 8/3000
# 92/92 - 0s - loss: 2.3817e-04 - acc: 1.0000 - val_loss: 0.4741 - val_acc: 0.8000
# Epoch 9/3000
# 92/92 - 0s - loss: 6.3077e-05 - acc: 1.0000 - val_loss: 0.4654 - val_acc: 0.7000
# Epoch 10/3000
# 92/92 - 0s - loss: 2.3119e-05 - acc: 1.0000 - val_loss: 0.4605 - val_acc: 0.7500
# Epoch 11/3000
# 92/92 - 0s - loss: 1.0140e-05 - acc: 1.0000 - val_loss: 0.4576 - val_acc: 0.7500
# Epoch 12/3000
# 92/92 - 0s - loss: 5.5776e-06 - acc: 1.0000 - val_loss: 0.4560 - val_acc: 0.7500
# Epoch 13/3000
# 92/92 - 0s - loss: 3.3270e-06 - acc: 1.0000 - val_loss: 0.4551 - val_acc: 0.7500
# Epoch 14/3000
# 92/92 - 0s - loss: 2.2818e-06 - acc: 1.0000 - val_loss: 0.4545 - val_acc: 0.7500
# Epoch 15/3000
# 92/92 - 0s - loss: 1.7512e-06 - acc: 1.0000 - val_loss: 0.4542 - val_acc: 0.7500
# Epoch 16/3000
# 92/92 - 0s - loss: 1.4232e-06 - acc: 1.0000 - val_loss: 0.4540 - val_acc: 0.7500
# Epoch 17/3000
# 92/92 - 0s - loss: 1.1884e-06 - acc: 1.0000 - val_loss: 0.4539 - val_acc: 0.7500
# Epoch 18/3000
# 92/92 - 0s - loss: 1.0522e-06 - acc: 1.0000 - val_loss: 0.4537 - val_acc: 0.7500
# Epoch 19/3000
# 92/92 - 0s - loss: 9.5193e-07 - acc: 1.0000 - val_loss: 0.4537 - val_acc: 0.7500
# Epoch 20/3000
# 92/92 - 0s - loss: 8.9055e-07 - acc: 1.0000 - val_loss: 0.4536 - val_acc: 0.7500
# Epoch 21/3000
# 92/92 - 0s - loss: 8.4394e-07 - acc: 1.0000 - val_loss: 0.4535 - val_acc: 0.7500
# Epoch 22/3000
# 92/92 - 0s - loss: 8.0441e-07 - acc: 1.0000 - val_loss: 0.4535 - val_acc: 0.7500
# Epoch 23/3000
# 92/92 - 0s - loss: 7.8361e-07 - acc: 1.0000 - val_loss: 0.4534 - val_acc: 0.7500
# Epoch 24/3000
# 92/92 - 0s - loss: 7.6571e-07 - acc: 1.0000 - val_loss: 0.4534 - val_acc: 0.7500
# Epoch 25/3000
# 92/92 - 0s - loss: 7.5203e-07 - acc: 1.0000 - val_loss: 0.4533 - val_acc: 0.7500
# Epoch 26/3000
# 92/92 - 0s - loss: 7.4281e-07 - acc: 1.0000 - val_loss: 0.4533 - val_acc: 0.7500
# Epoch 27/3000
# 92/92 - 0s - loss: 7.3534e-07 - acc: 1.0000 - val_loss: 0.4532 - val_acc: 0.7500
# Epoch 28/3000
# 92/92 - 0s - loss: 7.2908e-07 - acc: 1.0000 - val_loss: 0.4532 - val_acc: 0.7500
# Epoch 29/3000
# 92/92 - 0s - loss: 7.2489e-07 - acc: 1.0000 - val_loss: 0.4531 - val_acc: 0.7500
# Epoch 30/3000
# 92/92 - 0s - loss: 7.2143e-07 - acc: 1.0000 - val_loss: 0.4531 - val_acc: 0.7500
# Epoch 31/3000
# 92/92 - 0s - loss: 7.1871e-07 - acc: 1.0000 - val_loss: 0.4530 - val_acc: 0.7500
# Epoch 32/3000
# 92/92 - 0s - loss: 7.1652e-07 - acc: 1.0000 - val_loss: 0.4529 - val_acc: 0.7500
# Epoch 33/3000
# 92/92 - 0s - loss: 7.1467e-07 - acc: 1.0000 - val_loss: 0.4529 - val_acc: 0.7500
# Epoch 34/3000
# 92/92 - 0s - loss: 7.1321e-07 - acc: 1.0000 - val_loss: 0.4528 - val_acc: 0.7500
# Epoch 35/3000
# 92/92 - 0s - loss: 7.1185e-07 - acc: 1.0000 - val_loss: 0.4528 - val_acc: 0.7500
# Epoch 36/3000
# 92/92 - 0s - loss: 7.1061e-07 - acc: 1.0000 - val_loss: 0.4527 - val_acc: 0.7500
# Epoch 37/3000
# 92/92 - 0s - loss: 7.0943e-07 - acc: 1.0000 - val_loss: 0.4527 - val_acc: 0.7500
# Epoch 38/3000
# 92/92 - 0s - loss: 7.0852e-07 - acc: 1.0000 - val_loss: 0.4526 - val_acc: 0.7500
# Epoch 39/3000
# 92/92 - 0s - loss: 7.0749e-07 - acc: 1.0000 - val_loss: 0.4525 - val_acc: 0.7500
# Epoch 40/3000
# 92/92 - 0s - loss: 7.0671e-07 - acc: 1.0000 - val_loss: 0.4525 - val_acc: 0.7500
# Epoch 41/3000
# 92/92 - 0s - loss: 7.0564e-07 - acc: 1.0000 - val_loss: 0.4524 - val_acc: 0.7500
# Epoch 42/3000
# 92/92 - 0s - loss: 7.0474e-07 - acc: 1.0000 - val_loss: 0.4524 - val_acc: 0.7500
# Epoch 43/3000
# 92/92 - 0s - loss: 7.0405e-07 - acc: 1.0000 - val_loss: 0.4523 - val_acc: 0.7500
# Epoch 44/3000
# 92/92 - 0s - loss: 7.0308e-07 - acc: 1.0000 - val_loss: 0.4522 - val_acc: 0.7500
# Epoch 45/3000
# 92/92 - 0s - loss: 7.0235e-07 - acc: 1.0000 - val_loss: 0.4522 - val_acc: 0.7500
# Epoch 46/3000
# 92/92 - 0s - loss: 7.0152e-07 - acc: 1.0000 - val_loss: 0.4521 - val_acc: 0.7500
# Epoch 47/3000
# 92/92 - 0s - loss: 7.0065e-07 - acc: 1.0000 - val_loss: 0.4521 - val_acc: 0.7500
# Epoch 48/3000
# 92/92 - 0s - loss: 6.9989e-07 - acc: 1.0000 - val_loss: 0.4520 - val_acc: 0.7500
# Epoch 49/3000
# 92/92 - 0s - loss: 6.9898e-07 - acc: 1.0000 - val_loss: 0.4519 - val_acc: 0.7500
# Epoch 50/3000
# 92/92 - 0s - loss: 6.9807e-07 - acc: 1.0000 - val_loss: 0.4519 - val_acc: 0.7500
# Epoch 51/3000
# 92/92 - 0s - loss: 6.9724e-07 - acc: 1.0000 - val_loss: 0.4518 - val_acc: 0.7500
# Epoch 52/3000
# 92/92 - 0s - loss: 6.9642e-07 - acc: 1.0000 - val_loss: 0.4518 - val_acc: 0.7500
# Epoch 53/3000
# 92/92 - 0s - loss: 6.9554e-07 - acc: 1.0000 - val_loss: 0.4517 - val_acc: 0.7500
# Epoch 54/3000
# 92/92 - 0s - loss: 6.9466e-07 - acc: 1.0000 - val_loss: 0.4516 - val_acc: 0.7500
# Epoch 55/3000
# 92/92 - 0s - loss: 6.9376e-07 - acc: 1.0000 - val_loss: 0.4516 - val_acc: 0.7500
# Epoch 56/3000
# 92/92 - 0s - loss: 6.9297e-07 - acc: 1.0000 - val_loss: 0.4515 - val_acc: 0.7500
# Epoch 57/3000
# 92/92 - 0s - loss: 6.9204e-07 - acc: 1.0000 - val_loss: 0.4514 - val_acc: 0.7500
# Epoch 58/3000
# 92/92 - 0s - loss: 6.9118e-07 - acc: 1.0000 - val_loss: 0.4514 - val_acc: 0.7500
# Epoch 59/3000
# 92/92 - 0s - loss: 6.9028e-07 - acc: 1.0000 - val_loss: 0.4513 - val_acc: 0.7500
# Epoch 60/3000
# 92/92 - 0s - loss: 6.8942e-07 - acc: 1.0000 - val_loss: 0.4512 - val_acc: 0.7500
# Epoch 61/3000
# 92/92 - 0s - loss: 6.8856e-07 - acc: 1.0000 - val_loss: 0.4512 - val_acc: 0.7500
# Epoch 62/3000
# 92/92 - 0s - loss: 6.8759e-07 - acc: 1.0000 - val_loss: 0.4511 - val_acc: 0.7500
# Epoch 63/3000
# 92/92 - 0s - loss: 6.8663e-07 - acc: 1.0000 - val_loss: 0.4510 - val_acc: 0.7500
# Epoch 64/3000
# 92/92 - 0s - loss: 6.8583e-07 - acc: 1.0000 - val_loss: 0.4510 - val_acc: 0.7500
# Epoch 65/3000
# 92/92 - 0s - loss: 6.8498e-07 - acc: 1.0000 - val_loss: 0.4509 - val_acc: 0.7500
# Epoch 66/3000
# 92/92 - 0s - loss: 6.8400e-07 - acc: 1.0000 - val_loss: 0.4508 - val_acc: 0.7500
# Epoch 67/3000
# 92/92 - 0s - loss: 6.8294e-07 - acc: 1.0000 - val_loss: 0.4508 - val_acc: 0.7500
# Epoch 68/3000
# 92/92 - 0s - loss: 6.8209e-07 - acc: 1.0000 - val_loss: 0.4507 - val_acc: 0.7500
# Epoch 69/3000
# 92/92 - 0s - loss: 6.8132e-07 - acc: 1.0000 - val_loss: 0.4507 - val_acc: 0.7500
# Epoch 70/3000
# 92/92 - 0s - loss: 6.8034e-07 - acc: 1.0000 - val_loss: 0.4506 - val_acc: 0.7500
# Epoch 71/3000
# 92/92 - 0s - loss: 6.7925e-07 - acc: 1.0000 - val_loss: 0.4505 - val_acc: 0.7500
# Epoch 72/3000
# 92/92 - 0s - loss: 6.7839e-07 - acc: 1.0000 - val_loss: 0.4505 - val_acc: 0.7500
# Epoch 73/3000
# 92/92 - 0s - loss: 6.7748e-07 - acc: 1.0000 - val_loss: 0.4504 - val_acc: 0.7500
# Epoch 74/3000
# 92/92 - 0s - loss: 6.7649e-07 - acc: 1.0000 - val_loss: 0.4503 - val_acc: 0.7500
# Epoch 75/3000
# 92/92 - 0s - loss: 6.7570e-07 - acc: 1.0000 - val_loss: 0.4503 - val_acc: 0.7500
# Epoch 76/3000
# 92/92 - 0s - loss: 6.7471e-07 - acc: 1.0000 - val_loss: 0.4502 - val_acc: 0.7500
# Epoch 77/3000
# 92/92 - 0s - loss: 6.7369e-07 - acc: 1.0000 - val_loss: 0.4501 - val_acc: 0.7500
# Epoch 78/3000
# 92/92 - 0s - loss: 6.7267e-07 - acc: 1.0000 - val_loss: 0.4501 - val_acc: 0.7500
# Epoch 79/3000
# 92/92 - 0s - loss: 6.7172e-07 - acc: 1.0000 - val_loss: 0.4500 - val_acc: 0.7500
# Epoch 80/3000
# 92/92 - 0s - loss: 6.7076e-07 - acc: 1.0000 - val_loss: 0.4499 - val_acc: 0.7500
# Epoch 81/3000
# 92/92 - 0s - loss: 6.6983e-07 - acc: 1.0000 - val_loss: 0.4499 - val_acc: 0.7500
# Epoch 82/3000
# 92/92 - 0s - loss: 6.6874e-07 - acc: 1.0000 - val_loss: 0.4498 - val_acc: 0.7500
# Epoch 83/3000
# 92/92 - 0s - loss: 6.6800e-07 - acc: 1.0000 - val_loss: 0.4497 - val_acc: 0.7500
# Epoch 84/3000
# 92/92 - 0s - loss: 6.6700e-07 - acc: 1.0000 - val_loss: 0.4497 - val_acc: 0.7500
# Epoch 85/3000
# 92/92 - 0s - loss: 6.6593e-07 - acc: 1.0000 - val_loss: 0.4496 - val_acc: 0.7500
# Epoch 86/3000
# 92/92 - 0s - loss: 6.6490e-07 - acc: 1.0000 - val_loss: 0.4495 - val_acc: 0.7500
# Epoch 87/3000
# 92/92 - 0s - loss: 6.6401e-07 - acc: 1.0000 - val_loss: 0.4495 - val_acc: 0.7500
# Epoch 88/3000
# 92/92 - 0s - loss: 6.6304e-07 - acc: 1.0000 - val_loss: 0.4494 - val_acc: 0.7500
# Epoch 89/3000
# 92/92 - 0s - loss: 6.6213e-07 - acc: 1.0000 - val_loss: 0.4493 - val_acc: 0.7500
# Epoch 90/3000
# 92/92 - 0s - loss: 6.6091e-07 - acc: 1.0000 - val_loss: 0.4493 - val_acc: 0.7500
# Epoch 91/3000
# 92/92 - 0s - loss: 6.6006e-07 - acc: 1.0000 - val_loss: 0.4492 - val_acc: 0.7500
# Epoch 92/3000
# 92/92 - 0s - loss: 6.5908e-07 - acc: 1.0000 - val_loss: 0.4491 - val_acc: 0.7500
# Epoch 93/3000
# 92/92 - 0s - loss: 6.5819e-07 - acc: 1.0000 - val_loss: 0.4491 - val_acc: 0.7500
# Epoch 94/3000
# 92/92 - 0s - loss: 6.5702e-07 - acc: 1.0000 - val_loss: 0.4490 - val_acc: 0.7500
# Epoch 95/3000
# 92/92 - 0s - loss: 6.5608e-07 - acc: 1.0000 - val_loss: 0.4489 - val_acc: 0.7500
# Epoch 96/3000
# 92/92 - 0s - loss: 6.5516e-07 - acc: 1.0000 - val_loss: 0.4489 - val_acc: 0.7500
# Epoch 97/3000
# 92/92 - 0s - loss: 6.5413e-07 - acc: 1.0000 - val_loss: 0.4488 - val_acc: 0.7500
# Epoch 98/3000
# 92/92 - 0s - loss: 6.5304e-07 - acc: 1.0000 - val_loss: 0.4487 - val_acc: 0.7500
# Epoch 99/3000
# 92/92 - 0s - loss: 6.5214e-07 - acc: 1.0000 - val_loss: 0.4487 - val_acc: 0.7500
# Epoch 100/3000
# 92/92 - 0s - loss: 6.5106e-07 - acc: 1.0000 - val_loss: 0.4486 - val_acc: 0.7500
# Epoch 101/3000
# 92/92 - 0s - loss: 6.5009e-07 - acc: 1.0000 - val_loss: 0.4485 - val_acc: 0.7500
# Epoch 102/3000
# 92/92 - 0s - loss: 6.4901e-07 - acc: 1.0000 - val_loss: 0.4485 - val_acc: 0.7500
# Epoch 103/3000
# 92/92 - 0s - loss: 6.4820e-07 - acc: 1.0000 - val_loss: 0.4484 - val_acc: 0.7500
# Epoch 104/3000
# 92/92 - 0s - loss: 6.4711e-07 - acc: 1.0000 - val_loss: 0.4483 - val_acc: 0.7500
# Epoch 105/3000
# 92/92 - 0s - loss: 6.4602e-07 - acc: 1.0000 - val_loss: 0.4483 - val_acc: 0.7500
# Epoch 106/3000
# 92/92 - 0s - loss: 6.4492e-07 - acc: 1.0000 - val_loss: 0.4482 - val_acc: 0.7500
# Epoch 107/3000
# 92/92 - 0s - loss: 6.4401e-07 - acc: 1.0000 - val_loss: 0.4481 - val_acc: 0.7500
# Epoch 108/3000
# 92/92 - 0s - loss: 6.4306e-07 - acc: 1.0000 - val_loss: 0.4481 - val_acc: 0.7500
# Epoch 109/3000
# 92/92 - 0s - loss: 6.4201e-07 - acc: 1.0000 - val_loss: 0.4480 - val_acc: 0.7500
# Epoch 110/3000
# 92/92 - 0s - loss: 6.4097e-07 - acc: 1.0000 - val_loss: 0.4479 - val_acc: 0.7500
# Epoch 111/3000
# 92/92 - 0s - loss: 6.4012e-07 - acc: 1.0000 - val_loss: 0.4479 - val_acc: 0.7500
# Epoch 112/3000
# 92/92 - 0s - loss: 6.3900e-07 - acc: 1.0000 - val_loss: 0.4478 - val_acc: 0.7500
# Epoch 113/3000
# 92/92 - 0s - loss: 6.3780e-07 - acc: 1.0000 - val_loss: 0.4477 - val_acc: 0.7500
# Epoch 114/3000
# 92/92 - 0s - loss: 6.3709e-07 - acc: 1.0000 - val_loss: 0.4477 - val_acc: 0.7500
# Epoch 115/3000
# 92/92 - 0s - loss: 6.3586e-07 - acc: 1.0000 - val_loss: 0.4476 - val_acc: 0.7500
# Epoch 116/3000
# 92/92 - 0s - loss: 6.3496e-07 - acc: 1.0000 - val_loss: 0.4475 - val_acc: 0.7500
# Epoch 117/3000
# 92/92 - 0s - loss: 6.3400e-07 - acc: 1.0000 - val_loss: 0.4475 - val_acc: 0.7500
# Epoch 118/3000
# 92/92 - 0s - loss: 6.3285e-07 - acc: 1.0000 - val_loss: 0.4474 - val_acc: 0.7500
# Epoch 119/3000
# 92/92 - 0s - loss: 6.3183e-07 - acc: 1.0000 - val_loss: 0.4474 - val_acc: 0.7500
# Epoch 120/3000
# 92/92 - 0s - loss: 6.3092e-07 - acc: 1.0000 - val_loss: 0.4473 - val_acc: 0.7500
# Epoch 121/3000
# 92/92 - 0s - loss: 6.2985e-07 - acc: 1.0000 - val_loss: 0.4472 - val_acc: 0.7500
# Epoch 122/3000
# 92/92 - 0s - loss: 6.2890e-07 - acc: 1.0000 - val_loss: 0.4472 - val_acc: 0.7500
# Epoch 123/3000
# 92/92 - 0s - loss: 6.2785e-07 - acc: 1.0000 - val_loss: 0.4471 - val_acc: 0.7500
# Epoch 124/3000
# 92/92 - 0s - loss: 6.2684e-07 - acc: 1.0000 - val_loss: 0.4470 - val_acc: 0.7500
# Epoch 125/3000
# 92/92 - 0s - loss: 6.2589e-07 - acc: 1.0000 - val_loss: 0.4470 - val_acc: 0.7500
# Epoch 126/3000
# 92/92 - 0s - loss: 6.2481e-07 - acc: 1.0000 - val_loss: 0.4469 - val_acc: 0.7500
# Epoch 127/3000
# 92/92 - 0s - loss: 6.2376e-07 - acc: 1.0000 - val_loss: 0.4469 - val_acc: 0.7500
# Epoch 128/3000
# 92/92 - 0s - loss: 6.2284e-07 - acc: 1.0000 - val_loss: 0.4468 - val_acc: 0.7500
# Epoch 129/3000
# 92/92 - 0s - loss: 6.2177e-07 - acc: 1.0000 - val_loss: 0.4467 - val_acc: 0.7500
# Epoch 130/3000
# 92/92 - 0s - loss: 6.2081e-07 - acc: 1.0000 - val_loss: 0.4467 - val_acc: 0.7500
# Epoch 131/3000
# 92/92 - 0s - loss: 6.1992e-07 - acc: 1.0000 - val_loss: 0.4466 - val_acc: 0.7500
# Epoch 132/3000
# 92/92 - 0s - loss: 6.1877e-07 - acc: 1.0000 - val_loss: 0.4466 - val_acc: 0.7500
# Epoch 133/3000
# 92/92 - 0s - loss: 6.1772e-07 - acc: 1.0000 - val_loss: 0.4465 - val_acc: 0.7500
# Epoch 134/3000
# 92/92 - 0s - loss: 6.1673e-07 - acc: 1.0000 - val_loss: 0.4464 - val_acc: 0.7500
# Epoch 135/3000
# 92/92 - 0s - loss: 6.1580e-07 - acc: 1.0000 - val_loss: 0.4464 - val_acc: 0.7500
# Epoch 136/3000
# 92/92 - 0s - loss: 6.1475e-07 - acc: 1.0000 - val_loss: 0.4463 - val_acc: 0.7500
# Epoch 137/3000
# 92/92 - 0s - loss: 6.1373e-07 - acc: 1.0000 - val_loss: 0.4462 - val_acc: 0.7500
# Epoch 138/3000
# 92/92 - 0s - loss: 6.1276e-07 - acc: 1.0000 - val_loss: 0.4462 - val_acc: 0.7500
# Epoch 139/3000
# 92/92 - 0s - loss: 6.1163e-07 - acc: 1.0000 - val_loss: 0.4461 - val_acc: 0.7500
# Epoch 140/3000
# 92/92 - 0s - loss: 6.1074e-07 - acc: 1.0000 - val_loss: 0.4461 - val_acc: 0.7500
# Epoch 141/3000
# 92/92 - 0s - loss: 6.0966e-07 - acc: 1.0000 - val_loss: 0.4460 - val_acc: 0.7500
# Epoch 142/3000
# 92/92 - 0s - loss: 6.0871e-07 - acc: 1.0000 - val_loss: 0.4460 - val_acc: 0.7500
# Epoch 143/3000
# 92/92 - 0s - loss: 6.0772e-07 - acc: 1.0000 - val_loss: 0.4459 - val_acc: 0.7500
# Epoch 144/3000
# 92/92 - 0s - loss: 6.0675e-07 - acc: 1.0000 - val_loss: 0.4458 - val_acc: 0.7000
# Epoch 145/3000
# 92/92 - 0s - loss: 6.0569e-07 - acc: 1.0000 - val_loss: 0.4458 - val_acc: 0.7000
# Epoch 146/3000
# 92/92 - 0s - loss: 6.0472e-07 - acc: 1.0000 - val_loss: 0.4457 - val_acc: 0.7000
# Epoch 147/3000
# 92/92 - 0s - loss: 6.0351e-07 - acc: 1.0000 - val_loss: 0.4457 - val_acc: 0.7000
# Epoch 148/3000
# 92/92 - 0s - loss: 6.0265e-07 - acc: 1.0000 - val_loss: 0.4456 - val_acc: 0.7000
# Epoch 149/3000
# 92/92 - 0s - loss: 6.0157e-07 - acc: 1.0000 - val_loss: 0.4455 - val_acc: 0.7000
# Epoch 150/3000
# 92/92 - 0s - loss: 6.0061e-07 - acc: 1.0000 - val_loss: 0.4455 - val_acc: 0.7000
# Epoch 151/3000
# 92/92 - 0s - loss: 5.9954e-07 - acc: 1.0000 - val_loss: 0.4454 - val_acc: 0.7000
# Epoch 152/3000
# 92/92 - 0s - loss: 5.9869e-07 - acc: 1.0000 - val_loss: 0.4454 - val_acc: 0.7000
# Epoch 153/3000
# 92/92 - 0s - loss: 5.9759e-07 - acc: 1.0000 - val_loss: 0.4453 - val_acc: 0.7000
# Epoch 154/3000
# 92/92 - 0s - loss: 5.9652e-07 - acc: 1.0000 - val_loss: 0.4453 - val_acc: 0.7000
# Epoch 155/3000
# 92/92 - 0s - loss: 5.9556e-07 - acc: 1.0000 - val_loss: 0.4452 - val_acc: 0.7000
# Epoch 156/3000
# 92/92 - 0s - loss: 5.9454e-07 - acc: 1.0000 - val_loss: 0.4451 - val_acc: 0.7000
# Epoch 157/3000
# 92/92 - 0s - loss: 5.9364e-07 - acc: 1.0000 - val_loss: 0.4451 - val_acc: 0.7000
# Epoch 158/3000
# 92/92 - 0s - loss: 5.9254e-07 - acc: 1.0000 - val_loss: 0.4450 - val_acc: 0.7000
# Epoch 159/3000
# 92/92 - 0s - loss: 5.9157e-07 - acc: 1.0000 - val_loss: 0.4450 - val_acc: 0.7000
# Epoch 160/3000
# 92/92 - 0s - loss: 5.9055e-07 - acc: 1.0000 - val_loss: 0.4449 - val_acc: 0.7000
# Epoch 161/3000
# 92/92 - 0s - loss: 5.8945e-07 - acc: 1.0000 - val_loss: 0.4449 - val_acc: 0.7000
# Epoch 162/3000
# 92/92 - 0s - loss: 5.8861e-07 - acc: 1.0000 - val_loss: 0.4448 - val_acc: 0.7000
# Epoch 163/3000
# 92/92 - 0s - loss: 5.8749e-07 - acc: 1.0000 - val_loss: 0.4447 - val_acc: 0.7000
# Epoch 164/3000
# 92/92 - 0s - loss: 5.8654e-07 - acc: 1.0000 - val_loss: 0.4447 - val_acc: 0.7000
# Epoch 165/3000
# 92/92 - 0s - loss: 5.8553e-07 - acc: 1.0000 - val_loss: 0.4446 - val_acc: 0.7000
# Epoch 166/3000
# 92/92 - 0s - loss: 5.8455e-07 - acc: 1.0000 - val_loss: 0.4446 - val_acc: 0.7000
# Epoch 167/3000
# 92/92 - 0s - loss: 5.8360e-07 - acc: 1.0000 - val_loss: 0.4445 - val_acc: 0.7000
# Epoch 168/3000
# 92/92 - 0s - loss: 5.8258e-07 - acc: 1.0000 - val_loss: 0.4445 - val_acc: 0.7000
# Epoch 169/3000
# 92/92 - 0s - loss: 5.8153e-07 - acc: 1.0000 - val_loss: 0.4444 - val_acc: 0.7500
# Epoch 170/3000
# 92/92 - 0s - loss: 5.8059e-07 - acc: 1.0000 - val_loss: 0.4444 - val_acc: 0.8000
# Epoch 171/3000
# 92/92 - 0s - loss: 5.7969e-07 - acc: 1.0000 - val_loss: 0.4443 - val_acc: 0.8000
# Epoch 172/3000
# 92/92 - 0s - loss: 5.7867e-07 - acc: 1.0000 - val_loss: 0.4443 - val_acc: 0.8000
# Epoch 173/3000
# 92/92 - 0s - loss: 5.7767e-07 - acc: 1.0000 - val_loss: 0.4442 - val_acc: 0.8000
# Epoch 174/3000
# 92/92 - 0s - loss: 5.7669e-07 - acc: 1.0000 - val_loss: 0.4442 - val_acc: 0.8000
# Epoch 175/3000
# 92/92 - 0s - loss: 5.7573e-07 - acc: 1.0000 - val_loss: 0.4441 - val_acc: 0.8000
# Epoch 176/3000
# 92/92 - 0s - loss: 5.7468e-07 - acc: 1.0000 - val_loss: 0.4441 - val_acc: 0.8000
# Epoch 177/3000
# 92/92 - 0s - loss: 5.7375e-07 - acc: 1.0000 - val_loss: 0.4440 - val_acc: 0.8000
# Epoch 178/3000
# 92/92 - 0s - loss: 5.7269e-07 - acc: 1.0000 - val_loss: 0.4440 - val_acc: 0.8000
# Epoch 179/3000
# 92/92 - 0s - loss: 5.7184e-07 - acc: 1.0000 - val_loss: 0.4439 - val_acc: 0.8000
# Epoch 180/3000
# 92/92 - 0s - loss: 5.7086e-07 - acc: 1.0000 - val_loss: 0.4439 - val_acc: 0.8000
# Epoch 181/3000
# 92/92 - 0s - loss: 5.6983e-07 - acc: 1.0000 - val_loss: 0.4438 - val_acc: 0.8000
# Epoch 182/3000
# 92/92 - 0s - loss: 5.6887e-07 - acc: 1.0000 - val_loss: 0.4438 - val_acc: 0.8000
# Epoch 183/3000
# 92/92 - 0s - loss: 5.6782e-07 - acc: 1.0000 - val_loss: 0.4437 - val_acc: 0.8000
# Epoch 184/3000
# 92/92 - 0s - loss: 5.6694e-07 - acc: 1.0000 - val_loss: 0.4437 - val_acc: 0.8000
# Epoch 185/3000
# 92/92 - 0s - loss: 5.6601e-07 - acc: 1.0000 - val_loss: 0.4436 - val_acc: 0.8000
# Epoch 186/3000
# 92/92 - 0s - loss: 5.6511e-07 - acc: 1.0000 - val_loss: 0.4436 - val_acc: 0.8000
# Epoch 187/3000
# 92/92 - 0s - loss: 5.6407e-07 - acc: 1.0000 - val_loss: 0.4435 - val_acc: 0.8000
# Epoch 188/3000
# 92/92 - 0s - loss: 5.6312e-07 - acc: 1.0000 - val_loss: 0.4435 - val_acc: 0.8000
# Epoch 189/3000
# 92/92 - 0s - loss: 5.6215e-07 - acc: 1.0000 - val_loss: 0.4434 - val_acc: 0.8000
# Epoch 190/3000
# 92/92 - 0s - loss: 5.6117e-07 - acc: 1.0000 - val_loss: 0.4434 - val_acc: 0.8000
# Epoch 191/3000
# 92/92 - 0s - loss: 5.6028e-07 - acc: 1.0000 - val_loss: 0.4433 - val_acc: 0.8000
# Epoch 192/3000
# 92/92 - 0s - loss: 5.5925e-07 - acc: 1.0000 - val_loss: 0.4433 - val_acc: 0.8000
# Epoch 193/3000
# 92/92 - 0s - loss: 5.5820e-07 - acc: 1.0000 - val_loss: 0.4433 - val_acc: 0.8000
# Epoch 194/3000
# 92/92 - 0s - loss: 5.5733e-07 - acc: 1.0000 - val_loss: 0.4432 - val_acc: 0.8000
# Epoch 195/3000
# 92/92 - 0s - loss: 5.5639e-07 - acc: 1.0000 - val_loss: 0.4432 - val_acc: 0.8000
# Epoch 196/3000
# 92/92 - 0s - loss: 5.5543e-07 - acc: 1.0000 - val_loss: 0.4431 - val_acc: 0.8000
# Epoch 197/3000
# 92/92 - 0s - loss: 5.5452e-07 - acc: 1.0000 - val_loss: 0.4431 - val_acc: 0.8000
# Epoch 198/3000
# 92/92 - 0s - loss: 5.5352e-07 - acc: 1.0000 - val_loss: 0.4430 - val_acc: 0.8000
# Epoch 199/3000
# 92/92 - 0s - loss: 5.5266e-07 - acc: 1.0000 - val_loss: 0.4430 - val_acc: 0.8000
# Epoch 200/3000
# 92/92 - 0s - loss: 5.5157e-07 - acc: 1.0000 - val_loss: 0.4429 - val_acc: 0.8000
# Epoch 201/3000
# 92/92 - 0s - loss: 5.5074e-07 - acc: 1.0000 - val_loss: 0.4429 - val_acc: 0.8000
# Epoch 202/3000
# 92/92 - 0s - loss: 5.4972e-07 - acc: 1.0000 - val_loss: 0.4428 - val_acc: 0.8000
# Epoch 203/3000
# 92/92 - 0s - loss: 5.4880e-07 - acc: 1.0000 - val_loss: 0.4428 - val_acc: 0.8000
# Epoch 204/3000
# 92/92 - 0s - loss: 5.4778e-07 - acc: 1.0000 - val_loss: 0.4428 - val_acc: 0.8000
# Epoch 205/3000
# 92/92 - 0s - loss: 5.4693e-07 - acc: 1.0000 - val_loss: 0.4427 - val_acc: 0.8000
# Epoch 206/3000
# 92/92 - 0s - loss: 5.4589e-07 - acc: 1.0000 - val_loss: 0.4427 - val_acc: 0.8000
# Epoch 207/3000
# 92/92 - 0s - loss: 5.4483e-07 - acc: 1.0000 - val_loss: 0.4426 - val_acc: 0.8000
# Epoch 208/3000
# 92/92 - 0s - loss: 5.4399e-07 - acc: 1.0000 - val_loss: 0.4426 - val_acc: 0.8000
# Epoch 209/3000
# 92/92 - 0s - loss: 5.4310e-07 - acc: 1.0000 - val_loss: 0.4425 - val_acc: 0.8000
# Epoch 210/3000
# 92/92 - 0s - loss: 5.4207e-07 - acc: 1.0000 - val_loss: 0.4425 - val_acc: 0.8000
# Epoch 211/3000
# 92/92 - 0s - loss: 5.4108e-07 - acc: 1.0000 - val_loss: 0.4425 - val_acc: 0.8000
# Epoch 212/3000
# 92/92 - 0s - loss: 5.4018e-07 - acc: 1.0000 - val_loss: 0.4424 - val_acc: 0.8000
# Epoch 213/3000
# 92/92 - 0s - loss: 5.3930e-07 - acc: 1.0000 - val_loss: 0.4424 - val_acc: 0.8000
# Epoch 214/3000
# 92/92 - 0s - loss: 5.3826e-07 - acc: 1.0000 - val_loss: 0.4423 - val_acc: 0.8000
# Epoch 215/3000
# 92/92 - 0s - loss: 5.3739e-07 - acc: 1.0000 - val_loss: 0.4423 - val_acc: 0.8000
# Epoch 216/3000
# 92/92 - 0s - loss: 5.3637e-07 - acc: 1.0000 - val_loss: 0.4422 - val_acc: 0.8000
# Epoch 217/3000
# 92/92 - 0s - loss: 5.3559e-07 - acc: 1.0000 - val_loss: 0.4422 - val_acc: 0.8000
# Epoch 218/3000
# 92/92 - 0s - loss: 5.3446e-07 - acc: 1.0000 - val_loss: 0.4422 - val_acc: 0.8000
# Epoch 219/3000
# 92/92 - 0s - loss: 5.3353e-07 - acc: 1.0000 - val_loss: 0.4421 - val_acc: 0.8000
# Epoch 220/3000
# 92/92 - 0s - loss: 5.3266e-07 - acc: 1.0000 - val_loss: 0.4421 - val_acc: 0.8000
# Epoch 221/3000
# 92/92 - 0s - loss: 5.3177e-07 - acc: 1.0000 - val_loss: 0.4420 - val_acc: 0.8000
# Epoch 222/3000
# 92/92 - 0s - loss: 5.3087e-07 - acc: 1.0000 - val_loss: 0.4420 - val_acc: 0.8000
# Epoch 223/3000
# 92/92 - 0s - loss: 5.2981e-07 - acc: 1.0000 - val_loss: 0.4420 - val_acc: 0.8000
# Epoch 224/3000
# 92/92 - 0s - loss: 5.2885e-07 - acc: 1.0000 - val_loss: 0.4419 - val_acc: 0.8000
# Epoch 225/3000
# 92/92 - 0s - loss: 5.2793e-07 - acc: 1.0000 - val_loss: 0.4419 - val_acc: 0.8000
# Epoch 226/3000
# 92/92 - 0s - loss: 5.2711e-07 - acc: 1.0000 - val_loss: 0.4419 - val_acc: 0.8000
# Epoch 227/3000
# 92/92 - 0s - loss: 5.2609e-07 - acc: 1.0000 - val_loss: 0.4418 - val_acc: 0.8000
# Epoch 228/3000
# 92/92 - 0s - loss: 5.2524e-07 - acc: 1.0000 - val_loss: 0.4418 - val_acc: 0.8000
# Epoch 229/3000
# 92/92 - 0s - loss: 5.2422e-07 - acc: 1.0000 - val_loss: 0.4417 - val_acc: 0.8000
# Epoch 230/3000
# 92/92 - 0s - loss: 5.2336e-07 - acc: 1.0000 - val_loss: 0.4417 - val_acc: 0.8000
# Epoch 231/3000
# 92/92 - 0s - loss: 5.2253e-07 - acc: 1.0000 - val_loss: 0.4417 - val_acc: 0.8000
# Epoch 232/3000
# 92/92 - 0s - loss: 5.2160e-07 - acc: 1.0000 - val_loss: 0.4416 - val_acc: 0.8000
# Epoch 233/3000
# 92/92 - 0s - loss: 5.2053e-07 - acc: 1.0000 - val_loss: 0.4416 - val_acc: 0.8000
# Epoch 234/3000
# 92/92 - 0s - loss: 5.1966e-07 - acc: 1.0000 - val_loss: 0.4416 - val_acc: 0.8000
# Epoch 235/3000
# 92/92 - 0s - loss: 5.1882e-07 - acc: 1.0000 - val_loss: 0.4415 - val_acc: 0.8000
# Epoch 236/3000
# 92/92 - 0s - loss: 5.1785e-07 - acc: 1.0000 - val_loss: 0.4415 - val_acc: 0.8000
# Epoch 237/3000
# 92/92 - 0s - loss: 5.1696e-07 - acc: 1.0000 - val_loss: 0.4415 - val_acc: 0.8000
# Epoch 238/3000
# 92/92 - 0s - loss: 5.1601e-07 - acc: 1.0000 - val_loss: 0.4414 - val_acc: 0.8000
# Epoch 239/3000
# 92/92 - 0s - loss: 5.1520e-07 - acc: 1.0000 - val_loss: 0.4414 - val_acc: 0.8000
# Epoch 240/3000
# 92/92 - 0s - loss: 5.1425e-07 - acc: 1.0000 - val_loss: 0.4414 - val_acc: 0.8000
# Epoch 241/3000
# 92/92 - 0s - loss: 5.1334e-07 - acc: 1.0000 - val_loss: 0.4413 - val_acc: 0.8000
# Epoch 242/3000
# 92/92 - 0s - loss: 5.1240e-07 - acc: 1.0000 - val_loss: 0.4413 - val_acc: 0.8000
# Epoch 243/3000
# 92/92 - 0s - loss: 5.1161e-07 - acc: 1.0000 - val_loss: 0.4413 - val_acc: 0.8000
# Epoch 244/3000
# 92/92 - 0s - loss: 5.1063e-07 - acc: 1.0000 - val_loss: 0.4412 - val_acc: 0.8000
# Epoch 245/3000
# 92/92 - 0s - loss: 5.0971e-07 - acc: 1.0000 - val_loss: 0.4412 - val_acc: 0.8000
# Epoch 246/3000
# 92/92 - 0s - loss: 5.0880e-07 - acc: 1.0000 - val_loss: 0.4412 - val_acc: 0.8000
# Epoch 247/3000
# 92/92 - 0s - loss: 5.0802e-07 - acc: 1.0000 - val_loss: 0.4411 - val_acc: 0.8000
# Epoch 248/3000
# 92/92 - 0s - loss: 5.0702e-07 - acc: 1.0000 - val_loss: 0.4411 - val_acc: 0.8000
# Epoch 249/3000
# 92/92 - 0s - loss: 5.0616e-07 - acc: 1.0000 - val_loss: 0.4411 - val_acc: 0.8000
# Epoch 250/3000
# 92/92 - 0s - loss: 5.0523e-07 - acc: 1.0000 - val_loss: 0.4410 - val_acc: 0.8000
# Epoch 251/3000
# 92/92 - 0s - loss: 5.0429e-07 - acc: 1.0000 - val_loss: 0.4410 - val_acc: 0.8000
# Epoch 252/3000
# 92/92 - 0s - loss: 5.0353e-07 - acc: 1.0000 - val_loss: 0.4410 - val_acc: 0.8000
# Epoch 253/3000
# 92/92 - 0s - loss: 5.0257e-07 - acc: 1.0000 - val_loss: 0.4409 - val_acc: 0.8000
# Epoch 254/3000
# 92/92 - 0s - loss: 5.0169e-07 - acc: 1.0000 - val_loss: 0.4409 - val_acc: 0.8000
# Epoch 255/3000
# 92/92 - 0s - loss: 5.0075e-07 - acc: 1.0000 - val_loss: 0.4409 - val_acc: 0.8000
# Epoch 256/3000
# 92/92 - 0s - loss: 4.9987e-07 - acc: 1.0000 - val_loss: 0.4408 - val_acc: 0.8000
# Epoch 257/3000
# 92/92 - 0s - loss: 4.9897e-07 - acc: 1.0000 - val_loss: 0.4408 - val_acc: 0.8000
# Epoch 258/3000
# 92/92 - 0s - loss: 4.9823e-07 - acc: 1.0000 - val_loss: 0.4407 - val_acc: 0.8000
# Epoch 259/3000
# 92/92 - 0s - loss: 4.9712e-07 - acc: 1.0000 - val_loss: 0.4407 - val_acc: 0.8000
# Epoch 260/3000
# 92/92 - 0s - loss: 4.9643e-07 - acc: 1.0000 - val_loss: 0.4407 - val_acc: 0.8000
# Epoch 261/3000
# 92/92 - 0s - loss: 4.9536e-07 - acc: 1.0000 - val_loss: 0.4407 - val_acc: 0.8000
# Epoch 262/3000
# 92/92 - 0s - loss: 4.9448e-07 - acc: 1.0000 - val_loss: 0.4406 - val_acc: 0.8000
# Epoch 263/3000
# 92/92 - 0s - loss: 4.9376e-07 - acc: 1.0000 - val_loss: 0.4406 - val_acc: 0.8000
# Epoch 264/3000
# 92/92 - 0s - loss: 4.9278e-07 - acc: 1.0000 - val_loss: 0.4406 - val_acc: 0.8000
# Epoch 265/3000
# 92/92 - 0s - loss: 4.9187e-07 - acc: 1.0000 - val_loss: 0.4405 - val_acc: 0.8000
# Epoch 266/3000
# 92/92 - 0s - loss: 4.9109e-07 - acc: 1.0000 - val_loss: 0.4405 - val_acc: 0.8000
# Epoch 267/3000
# 92/92 - 0s - loss: 4.9021e-07 - acc: 1.0000 - val_loss: 0.4405 - val_acc: 0.8000
# Epoch 268/3000
# 92/92 - 0s - loss: 4.8921e-07 - acc: 1.0000 - val_loss: 0.4404 - val_acc: 0.8000
# Epoch 269/3000
# 92/92 - 0s - loss: 4.8845e-07 - acc: 1.0000 - val_loss: 0.4404 - val_acc: 0.8000
# Epoch 270/3000
# 92/92 - 0s - loss: 4.8753e-07 - acc: 1.0000 - val_loss: 0.4404 - val_acc: 0.8000
# Epoch 271/3000
# 92/92 - 0s - loss: 4.8663e-07 - acc: 1.0000 - val_loss: 0.4404 - val_acc: 0.8000
# Epoch 272/3000
# 92/92 - 0s - loss: 4.8577e-07 - acc: 1.0000 - val_loss: 0.4403 - val_acc: 0.8000
# Epoch 273/3000
# 92/92 - 0s - loss: 4.8492e-07 - acc: 1.0000 - val_loss: 0.4403 - val_acc: 0.8000
# Epoch 274/3000
# 92/92 - 0s - loss: 4.8412e-07 - acc: 1.0000 - val_loss: 0.4403 - val_acc: 0.8000
# Epoch 275/3000
# 92/92 - 0s - loss: 4.8316e-07 - acc: 1.0000 - val_loss: 0.4402 - val_acc: 0.8000
# Epoch 276/3000
# 92/92 - 0s - loss: 4.8230e-07 - acc: 1.0000 - val_loss: 0.4402 - val_acc: 0.8000
# Epoch 277/3000
# 92/92 - 0s - loss: 4.8152e-07 - acc: 1.0000 - val_loss: 0.4402 - val_acc: 0.8000
# Epoch 278/3000
# 92/92 - 0s - loss: 4.8057e-07 - acc: 1.0000 - val_loss: 0.4401 - val_acc: 0.8000
# Epoch 279/3000
# 92/92 - 0s - loss: 4.7967e-07 - acc: 1.0000 - val_loss: 0.4401 - val_acc: 0.8000
# Epoch 280/3000
# 92/92 - 0s - loss: 4.7897e-07 - acc: 1.0000 - val_loss: 0.4401 - val_acc: 0.8000
# Epoch 281/3000
# 92/92 - 0s - loss: 4.7800e-07 - acc: 1.0000 - val_loss: 0.4401 - val_acc: 0.8000
# Epoch 282/3000
# 92/92 - 0s - loss: 4.7717e-07 - acc: 1.0000 - val_loss: 0.4400 - val_acc: 0.8000
# Epoch 283/3000
# 92/92 - 0s - loss: 4.7631e-07 - acc: 1.0000 - val_loss: 0.4400 - val_acc: 0.8000
# Epoch 284/3000
# 92/92 - 0s - loss: 4.7541e-07 - acc: 1.0000 - val_loss: 0.4400 - val_acc: 0.8000
# Epoch 285/3000
# 92/92 - 0s - loss: 4.7456e-07 - acc: 1.0000 - val_loss: 0.4400 - val_acc: 0.8000
# Epoch 286/3000
# 92/92 - 0s - loss: 4.7379e-07 - acc: 1.0000 - val_loss: 0.4399 - val_acc: 0.8000
# Epoch 287/3000
# 92/92 - 0s - loss: 4.7299e-07 - acc: 1.0000 - val_loss: 0.4399 - val_acc: 0.8000
# Epoch 288/3000
# 92/92 - 0s - loss: 4.7213e-07 - acc: 1.0000 - val_loss: 0.4399 - val_acc: 0.8000
# Epoch 289/3000
# 92/92 - 0s - loss: 4.7117e-07 - acc: 1.0000 - val_loss: 0.4398 - val_acc: 0.8000
# Epoch 290/3000
# 92/92 - 0s - loss: 4.7038e-07 - acc: 1.0000 - val_loss: 0.4398 - val_acc: 0.8000
# Epoch 291/3000
# 92/92 - 0s - loss: 4.6949e-07 - acc: 1.0000 - val_loss: 0.4398 - val_acc: 0.8000
# Epoch 292/3000
# 92/92 - 0s - loss: 4.6866e-07 - acc: 1.0000 - val_loss: 0.4398 - val_acc: 0.8000
# Epoch 293/3000
# 92/92 - 0s - loss: 4.6792e-07 - acc: 1.0000 - val_loss: 0.4397 - val_acc: 0.8000
# Epoch 294/3000
# 92/92 - 0s - loss: 4.6694e-07 - acc: 1.0000 - val_loss: 0.4397 - val_acc: 0.8000
# Epoch 295/3000
# 92/92 - 0s - loss: 4.6618e-07 - acc: 1.0000 - val_loss: 0.4397 - val_acc: 0.8000
# Epoch 296/3000
# 92/92 - 0s - loss: 4.6530e-07 - acc: 1.0000 - val_loss: 0.4397 - val_acc: 0.8000
# Epoch 297/3000
# 92/92 - 0s - loss: 4.6448e-07 - acc: 1.0000 - val_loss: 0.4396 - val_acc: 0.8000
# Epoch 298/3000
# 92/92 - 0s - loss: 4.6363e-07 - acc: 1.0000 - val_loss: 0.4396 - val_acc: 0.8000
# Epoch 299/3000
# 92/92 - 0s - loss: 4.6289e-07 - acc: 1.0000 - val_loss: 0.4396 - val_acc: 0.8000
# Epoch 300/3000
# 92/92 - 0s - loss: 4.6197e-07 - acc: 1.0000 - val_loss: 0.4396 - val_acc: 0.8000
# Epoch 301/3000
# 92/92 - 0s - loss: 4.6109e-07 - acc: 1.0000 - val_loss: 0.4395 - val_acc: 0.8000
# Epoch 302/3000
# 92/92 - 0s - loss: 4.6034e-07 - acc: 1.0000 - val_loss: 0.4395 - val_acc: 0.8000
# Epoch 303/3000
# 92/92 - 0s - loss: 4.5950e-07 - acc: 1.0000 - val_loss: 0.4395 - val_acc: 0.8000
# Epoch 304/3000
# 92/92 - 0s - loss: 4.5871e-07 - acc: 1.0000 - val_loss: 0.4395 - val_acc: 0.8000
# Epoch 305/3000
# 92/92 - 0s - loss: 4.5776e-07 - acc: 1.0000 - val_loss: 0.4394 - val_acc: 0.8000
# Epoch 306/3000
# 92/92 - 0s - loss: 4.5701e-07 - acc: 1.0000 - val_loss: 0.4394 - val_acc: 0.8000
# Epoch 307/3000
# 92/92 - 0s - loss: 4.5622e-07 - acc: 1.0000 - val_loss: 0.4394 - val_acc: 0.8000
# Epoch 308/3000
# 92/92 - 0s - loss: 4.5538e-07 - acc: 1.0000 - val_loss: 0.4394 - val_acc: 0.8000
# Epoch 309/3000
# 92/92 - 0s - loss: 4.5452e-07 - acc: 1.0000 - val_loss: 0.4394 - val_acc: 0.8000
# Epoch 310/3000
# 92/92 - 0s - loss: 4.5375e-07 - acc: 1.0000 - val_loss: 0.4393 - val_acc: 0.8000
# Epoch 311/3000
# 92/92 - 0s - loss: 4.5292e-07 - acc: 1.0000 - val_loss: 0.4393 - val_acc: 0.8000
# Epoch 312/3000
# 92/92 - 0s - loss: 4.5208e-07 - acc: 1.0000 - val_loss: 0.4393 - val_acc: 0.8000
# Epoch 313/3000
# 92/92 - 0s - loss: 4.5122e-07 - acc: 1.0000 - val_loss: 0.4393 - val_acc: 0.8000
# Epoch 314/3000
# 92/92 - 0s - loss: 4.5047e-07 - acc: 1.0000 - val_loss: 0.4392 - val_acc: 0.8000
# Epoch 315/3000
# 92/92 - 0s - loss: 4.4960e-07 - acc: 1.0000 - val_loss: 0.4392 - val_acc: 0.8000
# Epoch 316/3000
# 92/92 - 0s - loss: 4.4879e-07 - acc: 1.0000 - val_loss: 0.4392 - val_acc: 0.8000
# Epoch 317/3000
# 92/92 - 0s - loss: 4.4804e-07 - acc: 1.0000 - val_loss: 0.4392 - val_acc: 0.8000
# Epoch 318/3000
# 92/92 - 0s - loss: 4.4723e-07 - acc: 1.0000 - val_loss: 0.4392 - val_acc: 0.8000
# Epoch 319/3000
# 92/92 - 0s - loss: 4.4636e-07 - acc: 1.0000 - val_loss: 0.4391 - val_acc: 0.8000
# Epoch 320/3000
# 92/92 - 0s - loss: 4.4558e-07 - acc: 1.0000 - val_loss: 0.4391 - val_acc: 0.8000
# Epoch 321/3000
# 92/92 - 0s - loss: 4.4478e-07 - acc: 1.0000 - val_loss: 0.4391 - val_acc: 0.8000
# Epoch 322/3000
# 92/92 - 0s - loss: 4.4397e-07 - acc: 1.0000 - val_loss: 0.4391 - val_acc: 0.8000
# Epoch 323/3000
# 92/92 - 0s - loss: 4.4311e-07 - acc: 1.0000 - val_loss: 0.4391 - val_acc: 0.8000
# Epoch 324/3000
# 92/92 - 0s - loss: 4.4238e-07 - acc: 1.0000 - val_loss: 0.4390 - val_acc: 0.8000
# Epoch 325/3000
# 92/92 - 0s - loss: 4.4157e-07 - acc: 1.0000 - val_loss: 0.4390 - val_acc: 0.8000
# Epoch 326/3000
# 92/92 - 0s - loss: 4.4075e-07 - acc: 1.0000 - val_loss: 0.4390 - val_acc: 0.8000
# Epoch 327/3000
# 92/92 - 0s - loss: 4.3998e-07 - acc: 1.0000 - val_loss: 0.4390 - val_acc: 0.8000
# Epoch 328/3000
# 92/92 - 0s - loss: 4.3919e-07 - acc: 1.0000 - val_loss: 0.4390 - val_acc: 0.8000
# Epoch 329/3000
# 92/92 - 0s - loss: 4.3840e-07 - acc: 1.0000 - val_loss: 0.4389 - val_acc: 0.8000
# Epoch 330/3000
# 92/92 - 0s - loss: 4.3759e-07 - acc: 1.0000 - val_loss: 0.4389 - val_acc: 0.8000
# Epoch 331/3000
# 92/92 - 0s - loss: 4.3668e-07 - acc: 1.0000 - val_loss: 0.4389 - val_acc: 0.8000
# Epoch 332/3000
# 92/92 - 0s - loss: 4.3605e-07 - acc: 1.0000 - val_loss: 0.4389 - val_acc: 0.8000
# Epoch 333/3000
# 92/92 - 0s - loss: 4.3521e-07 - acc: 1.0000 - val_loss: 0.4389 - val_acc: 0.8000
# Epoch 334/3000
# 92/92 - 0s - loss: 4.3440e-07 - acc: 1.0000 - val_loss: 0.4388 - val_acc: 0.8000
# Epoch 335/3000
# 92/92 - 0s - loss: 4.3351e-07 - acc: 1.0000 - val_loss: 0.4388 - val_acc: 0.8000
# Epoch 336/3000
# 92/92 - 0s - loss: 4.3290e-07 - acc: 1.0000 - val_loss: 0.4388 - val_acc: 0.8000
# Epoch 337/3000
# 92/92 - 0s - loss: 4.3207e-07 - acc: 1.0000 - val_loss: 0.4388 - val_acc: 0.8000
# Epoch 338/3000
# 92/92 - 0s - loss: 4.3125e-07 - acc: 1.0000 - val_loss: 0.4388 - val_acc: 0.8000
# Epoch 339/3000
# 92/92 - 0s - loss: 4.3053e-07 - acc: 1.0000 - val_loss: 0.4387 - val_acc: 0.8000
# Epoch 340/3000
# 92/92 - 0s - loss: 4.2966e-07 - acc: 1.0000 - val_loss: 0.4387 - val_acc: 0.8000
# Epoch 341/3000
# 92/92 - 0s - loss: 4.2884e-07 - acc: 1.0000 - val_loss: 0.4387 - val_acc: 0.8000
# Epoch 342/3000
# 92/92 - 0s - loss: 4.2815e-07 - acc: 1.0000 - val_loss: 0.4387 - val_acc: 0.8000
# Epoch 343/3000
# 92/92 - 0s - loss: 4.2730e-07 - acc: 1.0000 - val_loss: 0.4387 - val_acc: 0.8000
# Epoch 344/3000
# 92/92 - 0s - loss: 4.2653e-07 - acc: 1.0000 - val_loss: 0.4387 - val_acc: 0.8000
# Epoch 345/3000
# 92/92 - 0s - loss: 4.2579e-07 - acc: 1.0000 - val_loss: 0.4386 - val_acc: 0.8000
# Epoch 346/3000
# 92/92 - 0s - loss: 4.2506e-07 - acc: 1.0000 - val_loss: 0.4386 - val_acc: 0.8000
# Epoch 347/3000
# 92/92 - 0s - loss: 4.2419e-07 - acc: 1.0000 - val_loss: 0.4386 - val_acc: 0.8000
# Epoch 348/3000
# 92/92 - 0s - loss: 4.2343e-07 - acc: 1.0000 - val_loss: 0.4386 - val_acc: 0.8000
# Epoch 349/3000
# 92/92 - 0s - loss: 4.2268e-07 - acc: 1.0000 - val_loss: 0.4386 - val_acc: 0.8000
# Epoch 350/3000
# 92/92 - 0s - loss: 4.2190e-07 - acc: 1.0000 - val_loss: 0.4386 - val_acc: 0.8000
# Epoch 351/3000
# 92/92 - 0s - loss: 4.2115e-07 - acc: 1.0000 - val_loss: 0.4385 - val_acc: 0.8000
# Epoch 352/3000
# 92/92 - 0s - loss: 4.2036e-07 - acc: 1.0000 - val_loss: 0.4385 - val_acc: 0.8000
# Epoch 353/3000
# 92/92 - 0s - loss: 4.1959e-07 - acc: 1.0000 - val_loss: 0.4385 - val_acc: 0.8000
# Epoch 354/3000
# 92/92 - 0s - loss: 4.1885e-07 - acc: 1.0000 - val_loss: 0.4385 - val_acc: 0.8000
# Epoch 355/3000
# 92/92 - 0s - loss: 4.1806e-07 - acc: 1.0000 - val_loss: 0.4385 - val_acc: 0.8000
# Epoch 356/3000
# 92/92 - 0s - loss: 4.1732e-07 - acc: 1.0000 - val_loss: 0.4384 - val_acc: 0.8000
# Epoch 357/3000
# 92/92 - 0s - loss: 4.1657e-07 - acc: 1.0000 - val_loss: 0.4384 - val_acc: 0.8000
# Epoch 358/3000
# 92/92 - 0s - loss: 4.1573e-07 - acc: 1.0000 - val_loss: 0.4384 - val_acc: 0.8000
# Epoch 359/3000
# 92/92 - 0s - loss: 4.1506e-07 - acc: 1.0000 - val_loss: 0.4384 - val_acc: 0.8000
# Epoch 360/3000
# 92/92 - 0s - loss: 4.1423e-07 - acc: 1.0000 - val_loss: 0.4384 - val_acc: 0.8000
# Epoch 361/3000
# 92/92 - 0s - loss: 4.1346e-07 - acc: 1.0000 - val_loss: 0.4384 - val_acc: 0.8000
# Epoch 362/3000
# 92/92 - 0s - loss: 4.1274e-07 - acc: 1.0000 - val_loss: 0.4383 - val_acc: 0.8000
# Epoch 363/3000
# 92/92 - 0s - loss: 4.1199e-07 - acc: 1.0000 - val_loss: 0.4383 - val_acc: 0.8000
# Epoch 364/3000
# 92/92 - 0s - loss: 4.1126e-07 - acc: 1.0000 - val_loss: 0.4383 - val_acc: 0.8000
# Epoch 365/3000
# 92/92 - 0s - loss: 4.1050e-07 - acc: 1.0000 - val_loss: 0.4383 - val_acc: 0.8000
# Epoch 366/3000
# 92/92 - 0s - loss: 4.0968e-07 - acc: 1.0000 - val_loss: 0.4383 - val_acc: 0.8000
# Epoch 367/3000
# 92/92 - 0s - loss: 4.0896e-07 - acc: 1.0000 - val_loss: 0.4383 - val_acc: 0.8000
# Epoch 368/3000
# 92/92 - 0s - loss: 4.0815e-07 - acc: 1.0000 - val_loss: 0.4383 - val_acc: 0.8000
# Epoch 369/3000
# 92/92 - 0s - loss: 4.0751e-07 - acc: 1.0000 - val_loss: 0.4382 - val_acc: 0.8000
# Epoch 370/3000
# 92/92 - 0s - loss: 4.0670e-07 - acc: 1.0000 - val_loss: 0.4382 - val_acc: 0.8000
# Epoch 371/3000
# 92/92 - 0s - loss: 4.0596e-07 - acc: 1.0000 - val_loss: 0.4382 - val_acc: 0.8000
# Epoch 372/3000
# 92/92 - 0s - loss: 4.0527e-07 - acc: 1.0000 - val_loss: 0.4382 - val_acc: 0.8000
# Epoch 373/3000
# 92/92 - 0s - loss: 4.0446e-07 - acc: 1.0000 - val_loss: 0.4382 - val_acc: 0.8000
# Epoch 374/3000
# 92/92 - 0s - loss: 4.0371e-07 - acc: 1.0000 - val_loss: 0.4382 - val_acc: 0.8000
# Epoch 375/3000
# 92/92 - 0s - loss: 4.0300e-07 - acc: 1.0000 - val_loss: 0.4381 - val_acc: 0.8000
# Epoch 376/3000
# 92/92 - 0s - loss: 4.0226e-07 - acc: 1.0000 - val_loss: 0.4381 - val_acc: 0.8000
# Epoch 377/3000
# 92/92 - 0s - loss: 4.0147e-07 - acc: 1.0000 - val_loss: 0.4381 - val_acc: 0.8000
# Epoch 378/3000
# 92/92 - 0s - loss: 4.0070e-07 - acc: 1.0000 - val_loss: 0.4381 - val_acc: 0.8000
# Epoch 379/3000
# 92/92 - 0s - loss: 3.9999e-07 - acc: 1.0000 - val_loss: 0.4381 - val_acc: 0.8000
# Epoch 380/3000
# 92/92 - 0s - loss: 3.9930e-07 - acc: 1.0000 - val_loss: 0.4381 - val_acc: 0.8000
# Epoch 381/3000
# 92/92 - 0s - loss: 3.9850e-07 - acc: 1.0000 - val_loss: 0.4381 - val_acc: 0.8000
# Epoch 382/3000
# 92/92 - 0s - loss: 3.9779e-07 - acc: 1.0000 - val_loss: 0.4380 - val_acc: 0.8000
# Epoch 383/3000
# 92/92 - 0s - loss: 3.9711e-07 - acc: 1.0000 - val_loss: 0.4380 - val_acc: 0.8000
# Epoch 384/3000
# 92/92 - 0s - loss: 3.9630e-07 - acc: 1.0000 - val_loss: 0.4380 - val_acc: 0.8000
# Epoch 385/3000
# 92/92 - 0s - loss: 3.9561e-07 - acc: 1.0000 - val_loss: 0.4380 - val_acc: 0.8000
# Epoch 386/3000
# 92/92 - 0s - loss: 3.9490e-07 - acc: 1.0000 - val_loss: 0.4380 - val_acc: 0.8000
# Epoch 387/3000
# 92/92 - 0s - loss: 3.9414e-07 - acc: 1.0000 - val_loss: 0.4380 - val_acc: 0.8000
# Epoch 388/3000
# 92/92 - 0s - loss: 3.9336e-07 - acc: 1.0000 - val_loss: 0.4380 - val_acc: 0.8000
# Epoch 389/3000
# 92/92 - 0s - loss: 3.9273e-07 - acc: 1.0000 - val_loss: 0.4379 - val_acc: 0.8000
# Epoch 390/3000
# 92/92 - 0s - loss: 3.9193e-07 - acc: 1.0000 - val_loss: 0.4379 - val_acc: 0.8000
# Epoch 391/3000
# 92/92 - 0s - loss: 3.9119e-07 - acc: 1.0000 - val_loss: 0.4379 - val_acc: 0.8000
# Epoch 392/3000
# 92/92 - 0s - loss: 3.9055e-07 - acc: 1.0000 - val_loss: 0.4379 - val_acc: 0.8000
# Epoch 393/3000
# 92/92 - 0s - loss: 3.8981e-07 - acc: 1.0000 - val_loss: 0.4379 - val_acc: 0.8000
# Epoch 394/3000
# 92/92 - 0s - loss: 3.8906e-07 - acc: 1.0000 - val_loss: 0.4379 - val_acc: 0.8000
# Epoch 395/3000
# 92/92 - 0s - loss: 3.8832e-07 - acc: 1.0000 - val_loss: 0.4379 - val_acc: 0.8000
# Epoch 396/3000
# 92/92 - 0s - loss: 3.8761e-07 - acc: 1.0000 - val_loss: 0.4378 - val_acc: 0.8000
# Epoch 397/3000
# 92/92 - 0s - loss: 3.8688e-07 - acc: 1.0000 - val_loss: 0.4378 - val_acc: 0.8000
# Epoch 398/3000
# 92/92 - 0s - loss: 3.8618e-07 - acc: 1.0000 - val_loss: 0.4378 - val_acc: 0.8000
# Epoch 399/3000
# 92/92 - 0s - loss: 3.8552e-07 - acc: 1.0000 - val_loss: 0.4378 - val_acc: 0.8000
# Epoch 400/3000
# 92/92 - 0s - loss: 3.8480e-07 - acc: 1.0000 - val_loss: 0.4378 - val_acc: 0.8000
# Epoch 401/3000
# 92/92 - 0s - loss: 3.8408e-07 - acc: 1.0000 - val_loss: 0.4378 - val_acc: 0.8000
# Epoch 402/3000
# 92/92 - 0s - loss: 3.8334e-07 - acc: 1.0000 - val_loss: 0.4378 - val_acc: 0.8000
# Epoch 403/3000
# 92/92 - 0s - loss: 3.8260e-07 - acc: 1.0000 - val_loss: 0.4378 - val_acc: 0.8000
# Epoch 404/3000
# 92/92 - 0s - loss: 3.8198e-07 - acc: 1.0000 - val_loss: 0.4377 - val_acc: 0.8000
# Epoch 405/3000
# 92/92 - 0s - loss: 3.8121e-07 - acc: 1.0000 - val_loss: 0.4377 - val_acc: 0.8000
# Epoch 406/3000
# 92/92 - 0s - loss: 3.8051e-07 - acc: 1.0000 - val_loss: 0.4377 - val_acc: 0.8000
# Epoch 407/3000
# 92/92 - 0s - loss: 3.7979e-07 - acc: 1.0000 - val_loss: 0.4377 - val_acc: 0.8000
# Epoch 408/3000
# 92/92 - 0s - loss: 3.7914e-07 - acc: 1.0000 - val_loss: 0.4377 - val_acc: 0.8000
# Epoch 409/3000
# 92/92 - 0s - loss: 3.7843e-07 - acc: 1.0000 - val_loss: 0.4377 - val_acc: 0.8000
# Epoch 410/3000
# 92/92 - 0s - loss: 3.7769e-07 - acc: 1.0000 - val_loss: 0.4377 - val_acc: 0.8000
# Epoch 411/3000
# 92/92 - 0s - loss: 3.7709e-07 - acc: 1.0000 - val_loss: 0.4377 - val_acc: 0.8000
# Epoch 412/3000
# 92/92 - 0s - loss: 3.7632e-07 - acc: 1.0000 - val_loss: 0.4376 - val_acc: 0.8000
# Epoch 413/3000
# 92/92 - 0s - loss: 3.7566e-07 - acc: 1.0000 - val_loss: 0.4376 - val_acc: 0.8000
# Epoch 414/3000
# 92/92 - 0s - loss: 3.7496e-07 - acc: 1.0000 - val_loss: 0.4376 - val_acc: 0.8000
# Epoch 415/3000
# 92/92 - 0s - loss: 3.7427e-07 - acc: 1.0000 - val_loss: 0.4376 - val_acc: 0.8000
# Epoch 416/3000
# 92/92 - 0s - loss: 3.7354e-07 - acc: 1.0000 - val_loss: 0.4376 - val_acc: 0.8000
# Epoch 417/3000
# 92/92 - 0s - loss: 3.7295e-07 - acc: 1.0000 - val_loss: 0.4376 - val_acc: 0.8000
# Epoch 418/3000
# 92/92 - 0s - loss: 3.7218e-07 - acc: 1.0000 - val_loss: 0.4376 - val_acc: 0.8000
# Epoch 419/3000
# 92/92 - 0s - loss: 3.7157e-07 - acc: 1.0000 - val_loss: 0.4376 - val_acc: 0.8000
# Epoch 420/3000
# 92/92 - 0s - loss: 3.7087e-07 - acc: 1.0000 - val_loss: 0.4375 - val_acc: 0.8000
# Epoch 421/3000
# 92/92 - 0s - loss: 3.7015e-07 - acc: 1.0000 - val_loss: 0.4375 - val_acc: 0.8000
# Epoch 422/3000
# 92/92 - 0s - loss: 3.6952e-07 - acc: 1.0000 - val_loss: 0.4375 - val_acc: 0.8000
# Epoch 423/3000
# 92/92 - 0s - loss: 3.6882e-07 - acc: 1.0000 - val_loss: 0.4375 - val_acc: 0.8000
# Epoch 424/3000
# 92/92 - 0s - loss: 3.6813e-07 - acc: 1.0000 - val_loss: 0.4375 - val_acc: 0.8000
# Epoch 425/3000
# 92/92 - 0s - loss: 3.6747e-07 - acc: 1.0000 - val_loss: 0.4375 - val_acc: 0.8000
# Epoch 426/3000
# 92/92 - 0s - loss: 3.6678e-07 - acc: 1.0000 - val_loss: 0.4375 - val_acc: 0.8000
# Epoch 427/3000
# 92/92 - 0s - loss: 3.6612e-07 - acc: 1.0000 - val_loss: 0.4375 - val_acc: 0.8000
# Epoch 428/3000
# 92/92 - 0s - loss: 3.6549e-07 - acc: 1.0000 - val_loss: 0.4374 - val_acc: 0.8000
# Epoch 429/3000
# 92/92 - 0s - loss: 3.6477e-07 - acc: 1.0000 - val_loss: 0.4374 - val_acc: 0.8000
# Epoch 430/3000
# 92/92 - 0s - loss: 3.6411e-07 - acc: 1.0000 - val_loss: 0.4374 - val_acc: 0.8000
# Epoch 431/3000
# 92/92 - 0s - loss: 3.6343e-07 - acc: 1.0000 - val_loss: 0.4374 - val_acc: 0.8000
# Epoch 432/3000
# 92/92 - 0s - loss: 3.6276e-07 - acc: 1.0000 - val_loss: 0.4374 - val_acc: 0.8000
# Epoch 433/3000
# 92/92 - 0s - loss: 3.6208e-07 - acc: 1.0000 - val_loss: 0.4374 - val_acc: 0.8000
# Epoch 434/3000
# 92/92 - 0s - loss: 3.6146e-07 - acc: 1.0000 - val_loss: 0.4374 - val_acc: 0.8000
# Epoch 435/3000
# 92/92 - 0s - loss: 3.6075e-07 - acc: 1.0000 - val_loss: 0.4374 - val_acc: 0.8000
# Epoch 436/3000
# 92/92 - 0s - loss: 3.6013e-07 - acc: 1.0000 - val_loss: 0.4374 - val_acc: 0.8000
# Epoch 437/3000
# 92/92 - 0s - loss: 3.5944e-07 - acc: 1.0000 - val_loss: 0.4373 - val_acc: 0.8000
# Epoch 438/3000
# 92/92 - 0s - loss: 3.5879e-07 - acc: 1.0000 - val_loss: 0.4373 - val_acc: 0.8000
# Epoch 439/3000
# 92/92 - 0s - loss: 3.5813e-07 - acc: 1.0000 - val_loss: 0.4373 - val_acc: 0.8000
# Epoch 440/3000
# 92/92 - 0s - loss: 3.5750e-07 - acc: 1.0000 - val_loss: 0.4373 - val_acc: 0.8000
# Epoch 441/3000
# 92/92 - 0s - loss: 3.5681e-07 - acc: 1.0000 - val_loss: 0.4373 - val_acc: 0.8000
# Epoch 442/3000
# 92/92 - 0s - loss: 3.5621e-07 - acc: 1.0000 - val_loss: 0.4373 - val_acc: 0.8000
# Epoch 443/3000
# 92/92 - 0s - loss: 3.5555e-07 - acc: 1.0000 - val_loss: 0.4373 - val_acc: 0.8000
# Epoch 444/3000
# 92/92 - 0s - loss: 3.5490e-07 - acc: 1.0000 - val_loss: 0.4373 - val_acc: 0.8000
# Epoch 445/3000
# 92/92 - 0s - loss: 3.5425e-07 - acc: 1.0000 - val_loss: 0.4373 - val_acc: 0.8000
# Epoch 446/3000
# 92/92 - 0s - loss: 3.5363e-07 - acc: 1.0000 - val_loss: 0.4372 - val_acc: 0.8000
# Epoch 447/3000
# 92/92 - 0s - loss: 3.5292e-07 - acc: 1.0000 - val_loss: 0.4372 - val_acc: 0.8000
# Epoch 448/3000
# 92/92 - 0s - loss: 3.5231e-07 - acc: 1.0000 - val_loss: 0.4372 - val_acc: 0.8000
# Epoch 449/3000
# 92/92 - 0s - loss: 3.5162e-07 - acc: 1.0000 - val_loss: 0.4372 - val_acc: 0.8000
# Epoch 450/3000
# 92/92 - 0s - loss: 3.5102e-07 - acc: 1.0000 - val_loss: 0.4372 - val_acc: 0.8000
# Epoch 451/3000
# 92/92 - 0s - loss: 3.5041e-07 - acc: 1.0000 - val_loss: 0.4372 - val_acc: 0.8000
# Epoch 452/3000
# 92/92 - 0s - loss: 3.4980e-07 - acc: 1.0000 - val_loss: 0.4372 - val_acc: 0.8000
# Epoch 453/3000
# 92/92 - 0s - loss: 3.4913e-07 - acc: 1.0000 - val_loss: 0.4372 - val_acc: 0.8000
# Epoch 454/3000
# 92/92 - 0s - loss: 3.4845e-07 - acc: 1.0000 - val_loss: 0.4372 - val_acc: 0.8000
# Epoch 455/3000
# 92/92 - 0s - loss: 3.4786e-07 - acc: 1.0000 - val_loss: 0.4371 - val_acc: 0.8000
# Epoch 456/3000
# 92/92 - 0s - loss: 3.4728e-07 - acc: 1.0000 - val_loss: 0.4371 - val_acc: 0.8000
# Epoch 457/3000
# 92/92 - 0s - loss: 3.4658e-07 - acc: 1.0000 - val_loss: 0.4371 - val_acc: 0.8000
# Epoch 458/3000
# 92/92 - 0s - loss: 3.4591e-07 - acc: 1.0000 - val_loss: 0.4371 - val_acc: 0.8000
# Epoch 459/3000
# 92/92 - 0s - loss: 3.4539e-07 - acc: 1.0000 - val_loss: 0.4371 - val_acc: 0.8000
# Epoch 460/3000
# 92/92 - 0s - loss: 3.4478e-07 - acc: 1.0000 - val_loss: 0.4371 - val_acc: 0.8000
# Epoch 461/3000
# 92/92 - 0s - loss: 3.4408e-07 - acc: 1.0000 - val_loss: 0.4371 - val_acc: 0.8000
# Epoch 462/3000
# 92/92 - 0s - loss: 3.4344e-07 - acc: 1.0000 - val_loss: 0.4371 - val_acc: 0.8000
# Epoch 463/3000
# 92/92 - 0s - loss: 3.4284e-07 - acc: 1.0000 - val_loss: 0.4371 - val_acc: 0.8000
# Epoch 464/3000
# 92/92 - 0s - loss: 3.4225e-07 - acc: 1.0000 - val_loss: 0.4371 - val_acc: 0.8000
# Epoch 465/3000
# 92/92 - 0s - loss: 3.4162e-07 - acc: 1.0000 - val_loss: 0.4370 - val_acc: 0.8000
# Epoch 466/3000
# 92/92 - 0s - loss: 3.4099e-07 - acc: 1.0000 - val_loss: 0.4370 - val_acc: 0.8000
# Epoch 467/3000
# 92/92 - 0s - loss: 3.4042e-07 - acc: 1.0000 - val_loss: 0.4370 - val_acc: 0.8000
# Epoch 468/3000
# 92/92 - 0s - loss: 3.3980e-07 - acc: 1.0000 - val_loss: 0.4370 - val_acc: 0.8000
# Epoch 469/3000
# 92/92 - 0s - loss: 3.3914e-07 - acc: 1.0000 - val_loss: 0.4370 - val_acc: 0.8000
# Epoch 470/3000
# 92/92 - 0s - loss: 3.3861e-07 - acc: 1.0000 - val_loss: 0.4370 - val_acc: 0.8000
# Epoch 471/3000
# 92/92 - 0s - loss: 3.3795e-07 - acc: 1.0000 - val_loss: 0.4370 - val_acc: 0.8000
# Epoch 472/3000
# 92/92 - 0s - loss: 3.3736e-07 - acc: 1.0000 - val_loss: 0.4370 - val_acc: 0.8000
# Epoch 473/3000
# 92/92 - 0s - loss: 3.3677e-07 - acc: 1.0000 - val_loss: 0.4370 - val_acc: 0.8000
# Epoch 474/3000
# 92/92 - 0s - loss: 3.3611e-07 - acc: 1.0000 - val_loss: 0.4370 - val_acc: 0.8000
# Epoch 475/3000
# 92/92 - 0s - loss: 3.3551e-07 - acc: 1.0000 - val_loss: 0.4369 - val_acc: 0.8000
# Epoch 476/3000
# 92/92 - 0s - loss: 3.3495e-07 - acc: 1.0000 - val_loss: 0.4369 - val_acc: 0.8000
# Epoch 477/3000
# 92/92 - 0s - loss: 3.3434e-07 - acc: 1.0000 - val_loss: 0.4369 - val_acc: 0.8000
# Epoch 478/3000
# 92/92 - 0s - loss: 3.3375e-07 - acc: 1.0000 - val_loss: 0.4369 - val_acc: 0.8000
# Epoch 479/3000
# 92/92 - 0s - loss: 3.3314e-07 - acc: 1.0000 - val_loss: 0.4369 - val_acc: 0.8000
# Epoch 480/3000
# 92/92 - 0s - loss: 3.3253e-07 - acc: 1.0000 - val_loss: 0.4369 - val_acc: 0.8000
# Epoch 481/3000
# 92/92 - 0s - loss: 3.3190e-07 - acc: 1.0000 - val_loss: 0.4369 - val_acc: 0.8000
# Epoch 482/3000
# 92/92 - 0s - loss: 3.3133e-07 - acc: 1.0000 - val_loss: 0.4369 - val_acc: 0.8000
# Epoch 483/3000
# 92/92 - 0s - loss: 3.3074e-07 - acc: 1.0000 - val_loss: 0.4369 - val_acc: 0.8000
# Epoch 484/3000
# 92/92 - 0s - loss: 3.3017e-07 - acc: 1.0000 - val_loss: 0.4369 - val_acc: 0.8000
# Epoch 485/3000
# 92/92 - 0s - loss: 3.2956e-07 - acc: 1.0000 - val_loss: 0.4369 - val_acc: 0.8000
# Epoch 486/3000
# 92/92 - 0s - loss: 3.2900e-07 - acc: 1.0000 - val_loss: 0.4368 - val_acc: 0.8000
# Epoch 487/3000
# 92/92 - 0s - loss: 3.2838e-07 - acc: 1.0000 - val_loss: 0.4368 - val_acc: 0.8000
# Epoch 488/3000
# 92/92 - 0s - loss: 3.2780e-07 - acc: 1.0000 - val_loss: 0.4368 - val_acc: 0.8000
# Epoch 489/3000
# 92/92 - 0s - loss: 3.2723e-07 - acc: 1.0000 - val_loss: 0.4368 - val_acc: 0.8000
# Epoch 490/3000
# 92/92 - 0s - loss: 3.2659e-07 - acc: 1.0000 - val_loss: 0.4368 - val_acc: 0.8000
# Epoch 491/3000
# 92/92 - 0s - loss: 3.2600e-07 - acc: 1.0000 - val_loss: 0.4368 - val_acc: 0.8000
# Epoch 492/3000
# 92/92 - 0s - loss: 3.2540e-07 - acc: 1.0000 - val_loss: 0.4368 - val_acc: 0.8000
# Epoch 493/3000
# 92/92 - 0s - loss: 3.2487e-07 - acc: 1.0000 - val_loss: 0.4368 - val_acc: 0.8000
# Epoch 494/3000
# 92/92 - 0s - loss: 3.2429e-07 - acc: 1.0000 - val_loss: 0.4368 - val_acc: 0.8000
# Epoch 495/3000
# 92/92 - 0s - loss: 3.2368e-07 - acc: 1.0000 - val_loss: 0.4368 - val_acc: 0.8000
# Epoch 496/3000
# 92/92 - 0s - loss: 3.2313e-07 - acc: 1.0000 - val_loss: 0.4368 - val_acc: 0.8000
# Epoch 497/3000
# 92/92 - 0s - loss: 3.2253e-07 - acc: 1.0000 - val_loss: 0.4367 - val_acc: 0.8000
# Epoch 498/3000
# 92/92 - 0s - loss: 3.2194e-07 - acc: 1.0000 - val_loss: 0.4367 - val_acc: 0.8000
# Epoch 499/3000
# 92/92 - 0s - loss: 3.2140e-07 - acc: 1.0000 - val_loss: 0.4367 - val_acc: 0.8000
# Epoch 500/3000
# 92/92 - 0s - loss: 3.2075e-07 - acc: 1.0000 - val_loss: 0.4367 - val_acc: 0.8000
# Epoch 501/3000
# ...
# Epoch 1286/3000
# 92/92 - 0s - loss: 8.2919e-08 - acc: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000
# Epoch 1287/3000
# 92/92 - 0s - loss: 8.2783e-08 - acc: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000
# Epoch 1288/3000
# 92/92 - 0s - loss: 8.2651e-08 - acc: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000
# Epoch 1289/3000
# 92/92 - 0s - loss: 8.2507e-08 - acc: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000
# Epoch 1290/3000
# 92/92 - 0s - loss: 8.2369e-08 - acc: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000
# Epoch 1291/3000
# 92/92 - 0s - loss: 8.2237e-08 - acc: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000
# Epoch 1292/3000
# 92/92 - 0s - loss: 8.2097e-08 - acc: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000
# Epoch 1293/3000
# 92/92 - 0s - loss: 8.1960e-08 - acc: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000
# Epoch 1294/3000
# 92/92 - 0s - loss: 8.1833e-08 - acc: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000
# Epoch 1295/3000
# 92/92 - 0s - loss: 8.1692e-08 - acc: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000
# Epoch 1296/3000
# 92/92 - 0s - loss: 8.1560e-08 - acc: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000
# Epoch 1297/3000
# 92/92 - 0s - loss: 8.1416e-08 - acc: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000
# Epoch 1298/3000
# 92/92 - 0s - loss: 8.1293e-08 - acc: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000
# Epoch 1299/3000
# 92/92 - 0s - loss: 8.1161e-08 - acc: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000
# Epoch 1300/3000
# 92/92 - 0s - loss: 8.1016e-08 - acc: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000
# Epoch 1301/3000
# 92/92 - 0s - loss: 8.0888e-08 - acc: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000
# Epoch 1302/3000
# 92/92 - 0s - loss: 8.0747e-08 - acc: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000
# Epoch 1303/3000
# 92/92 - 0s - loss: 8.0616e-08 - acc: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000
# Epoch 1304/3000
# 92/92 - 0s - loss: 8.0477e-08 - acc: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000
# Epoch 1305/3000
# 92/92 - 0s - loss: 8.0351e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1306/3000
# 92/92 - 0s - loss: 8.0226e-08 - acc: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000
# Epoch 1307/3000
# 92/92 - 0s - loss: 8.0081e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1308/3000
# 92/92 - 0s - loss: 7.9957e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1309/3000
# 92/92 - 0s - loss: 7.9824e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1310/3000
# 92/92 - 0s - loss: 7.9696e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1311/3000
# 92/92 - 0s - loss: 7.9556e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1312/3000
# 92/92 - 0s - loss: 7.9427e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1313/3000
# 92/92 - 0s - loss: 7.9296e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1314/3000
# 92/92 - 0s - loss: 7.9169e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1315/3000
# 92/92 - 0s - loss: 7.9032e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1316/3000
# 92/92 - 0s - loss: 7.8908e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1317/3000
# 92/92 - 0s - loss: 7.8782e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1318/3000
# 92/92 - 0s - loss: 7.8640e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1319/3000
# 92/92 - 0s - loss: 7.8516e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1320/3000
# 92/92 - 0s - loss: 7.8387e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1321/3000
# 92/92 - 0s - loss: 7.8253e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1322/3000
# 92/92 - 0s - loss: 7.8129e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1323/3000
# 92/92 - 0s - loss: 7.7993e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1324/3000
# 92/92 - 0s - loss: 7.7859e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1325/3000
# 92/92 - 0s - loss: 7.7729e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1326/3000
# 92/92 - 0s - loss: 7.7620e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1327/3000
# 92/92 - 0s - loss: 7.7483e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1328/3000
# 92/92 - 0s - loss: 7.7351e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1329/3000
# 92/92 - 0s - loss: 7.7219e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1330/3000
# 92/92 - 0s - loss: 7.7094e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1331/3000
# 92/92 - 0s - loss: 7.6973e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1332/3000
# 92/92 - 0s - loss: 7.6838e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1333/3000
# 92/92 - 0s - loss: 7.6707e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1334/3000
# 92/92 - 0s - loss: 7.6582e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1335/3000
# 92/92 - 0s - loss: 7.6450e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1336/3000
# 92/92 - 0s - loss: 7.6321e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1337/3000
# 92/92 - 0s - loss: 7.6192e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1338/3000
# 92/92 - 0s - loss: 7.6072e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1339/3000
# 92/92 - 0s - loss: 7.5944e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1340/3000
# 92/92 - 0s - loss: 7.5819e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1341/3000
# 92/92 - 0s - loss: 7.5696e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1342/3000
# 92/92 - 0s - loss: 7.5566e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1343/3000
# 92/92 - 0s - loss: 7.5436e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1344/3000
# 92/92 - 0s - loss: 7.5317e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1345/3000
# 92/92 - 0s - loss: 7.5195e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1346/3000
# 92/92 - 0s - loss: 7.5065e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1347/3000
# 92/92 - 0s - loss: 7.4948e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1348/3000
# 92/92 - 0s - loss: 7.4815e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1349/3000
# 92/92 - 0s - loss: 7.4696e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1350/3000
# 92/92 - 0s - loss: 7.4569e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1351/3000
# 92/92 - 0s - loss: 7.4442e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1352/3000
# 92/92 - 0s - loss: 7.4327e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1353/3000
# 92/92 - 0s - loss: 7.4198e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1354/3000
# 92/92 - 0s - loss: 7.4073e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1355/3000
# 92/92 - 0s - loss: 7.3948e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1356/3000
# 92/92 - 0s - loss: 7.3827e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1357/3000
# 92/92 - 0s - loss: 7.3707e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1358/3000
# 92/92 - 0s - loss: 7.3590e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1359/3000
# 92/92 - 0s - loss: 7.3459e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1360/3000
# 92/92 - 0s - loss: 7.3342e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1361/3000
# 92/92 - 0s - loss: 7.3217e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1362/3000
# 92/92 - 0s - loss: 7.3103e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1363/3000
# 92/92 - 0s - loss: 7.2977e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1364/3000
# 92/92 - 0s - loss: 7.2852e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1365/3000
# 92/92 - 0s - loss: 7.2735e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1366/3000
# 92/92 - 0s - loss: 7.2613e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1367/3000
# 92/92 - 0s - loss: 7.2498e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1368/3000
# 92/92 - 0s - loss: 7.2369e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1369/3000
# 92/92 - 0s - loss: 7.2250e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1370/3000
# 92/92 - 0s - loss: 7.2137e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1371/3000
# 92/92 - 0s - loss: 7.2017e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1372/3000
# 92/92 - 0s - loss: 7.1892e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1373/3000
# 92/92 - 0s - loss: 7.1779e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1374/3000
# 92/92 - 0s - loss: 7.1664e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1375/3000
# 92/92 - 0s - loss: 7.1543e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1376/3000
# 92/92 - 0s - loss: 7.1419e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1377/3000
# 92/92 - 0s - loss: 7.1302e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1378/3000
# 92/92 - 0s - loss: 7.1180e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1379/3000
# 92/92 - 0s - loss: 7.1058e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1380/3000
# 92/92 - 0s - loss: 7.0936e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1381/3000
# 92/92 - 0s - loss: 7.0827e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1382/3000
# 92/92 - 0s - loss: 7.0709e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1383/3000
# 92/92 - 0s - loss: 7.0591e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1384/3000
# 92/92 - 0s - loss: 7.0468e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1385/3000
# 92/92 - 0s - loss: 7.0351e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1386/3000
# 92/92 - 0s - loss: 7.0232e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1387/3000
# 92/92 - 0s - loss: 7.0122e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1388/3000
# 92/92 - 0s - loss: 6.9998e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1389/3000
# 92/92 - 0s - loss: 6.9885e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1390/3000
# 92/92 - 0s - loss: 6.9761e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1391/3000
# 92/92 - 0s - loss: 6.9646e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1392/3000
# 92/92 - 0s - loss: 6.9534e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1393/3000
# 92/92 - 0s - loss: 6.9417e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1394/3000
# 92/92 - 0s - loss: 6.9295e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1395/3000
# 92/92 - 0s - loss: 6.9184e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1396/3000
# 92/92 - 0s - loss: 6.9072e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1397/3000
# 92/92 - 0s - loss: 6.8957e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1398/3000
# 92/92 - 0s - loss: 6.8839e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1399/3000
# 92/92 - 0s - loss: 6.8725e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1400/3000
# 92/92 - 0s - loss: 6.8602e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1401/3000
# 92/92 - 0s - loss: 6.8498e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1402/3000
# 92/92 - 0s - loss: 6.8379e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1403/3000
# 92/92 - 0s - loss: 6.8266e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1404/3000
# 92/92 - 0s - loss: 6.8149e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1405/3000
# 92/92 - 0s - loss: 6.8038e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1406/3000
# 92/92 - 0s - loss: 6.7929e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1407/3000
# 92/92 - 0s - loss: 6.7811e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1408/3000
# 92/92 - 0s - loss: 6.7700e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1409/3000
# 92/92 - 0s - loss: 6.7578e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1410/3000
# 92/92 - 0s - loss: 6.7466e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1411/3000
# 92/92 - 0s - loss: 6.7356e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1412/3000
# 92/92 - 0s - loss: 6.7236e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1413/3000
# 92/92 - 0s - loss: 6.7133e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1414/3000
# 92/92 - 0s - loss: 6.7020e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1415/3000
# 92/92 - 0s - loss: 6.6907e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1416/3000
# 92/92 - 0s - loss: 6.6790e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1417/3000
# 92/92 - 0s - loss: 6.6690e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1418/3000
# 92/92 - 0s - loss: 6.6570e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1419/3000
# 92/92 - 0s - loss: 6.6472e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1420/3000
# 92/92 - 0s - loss: 6.6356e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1421/3000
# 92/92 - 0s - loss: 6.6249e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1422/3000
# 92/92 - 0s - loss: 6.6149e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1423/3000
# 92/92 - 0s - loss: 6.6029e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1424/3000
# 92/92 - 0s - loss: 6.5924e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1425/3000
# 92/92 - 0s - loss: 6.5813e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1426/3000
# 92/92 - 0s - loss: 6.5718e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1427/3000
# 92/92 - 0s - loss: 6.5592e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1428/3000
# 92/92 - 0s - loss: 6.5497e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1429/3000
# 92/92 - 0s - loss: 6.5384e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1430/3000
# 92/92 - 0s - loss: 6.5278e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1431/3000
# 92/92 - 0s - loss: 6.5173e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1432/3000
# 92/92 - 0s - loss: 6.5061e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1433/3000
# 92/92 - 0s - loss: 6.4960e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1434/3000
# 92/92 - 0s - loss: 6.4855e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1435/3000
# 92/92 - 0s - loss: 6.4745e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1436/3000
# 92/92 - 0s - loss: 6.4636e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1437/3000
# 92/92 - 0s - loss: 6.4536e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1438/3000
# 92/92 - 0s - loss: 6.4423e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1439/3000
# 92/92 - 0s - loss: 6.4316e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1440/3000
# 92/92 - 0s - loss: 6.4213e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1441/3000
# 92/92 - 0s - loss: 6.4109e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1442/3000
# 92/92 - 0s - loss: 6.4006e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1443/3000
# 92/92 - 0s - loss: 6.3903e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1444/3000
# 92/92 - 0s - loss: 6.3787e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1445/3000
# 92/92 - 0s - loss: 6.3692e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1446/3000
# 92/92 - 0s - loss: 6.3584e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1447/3000
# 92/92 - 0s - loss: 6.3478e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1448/3000
# 92/92 - 0s - loss: 6.3376e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 1449/3000
# 92/92 - 0s - loss: 6.3277e-08 - acc: 1.0000 - val_loss: 0.4346 - val_acc: 0.8000
# Epoch 01449: early stopping

# %%
# PLOT THE LOSS

losses = pd.DataFrame(model.history.history)
losses.plot()
plt.title('Model loss and accuracy during training') 
plt.ylabel('Loss or Accuracy') 
plt.xlabel('Epochs')
plt.show()

# %%
# PERFORMANCE EVALUATION

pred_NN = []

for predictions in model.predict(X_test):
    if predictions < 0.5:
        predictions = 0
    else:
        predictions=1
    pred_NN.append(predictions)
    
pred = np.array(pred_NN)
true = np.array(y_test)

# print("PREDICTED CLASS: ", pred)
# print("ACTUAL CLASS: ", true, '\n')

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(classification_report(true, pred))
print('\n CONFUSION MATRIX:\n', confusion_matrix(true, pred))
print('\n\n ACCURACY SCORE IS:', accuracy_score(true, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.58      0.61        12
#            1       0.64      0.69      0.67        13
#
#     accuracy                           0.64        25
#    macro avg       0.64      0.64      0.64        25
# weighted avg       0.64      0.64      0.64        25
#
#
#  CONFUSION MATRIX:
#  [[7 5]
#  [4 9]]
#
#
#  ACCURACY SCORE IS: 0.64

# %%
# Classifier (Random Forest)
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=800)
rfc.fit(X_train,y_train)
pred_rfc = rfc.predict(X_test)
print('\n CONFUSION MATRIX:\n', confusion_matrix(true, pred_rfc))
print('\n\n ACCURACY SCORE IS:', accuracy_score(true, pred_rfc))
# Out:
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
#  CONFUSION MATRIX:
#  [[ 9  3]
#  [ 1 12]]
#
#
#  ACCURACY SCORE IS: 0.84

# %%
# Classifier (Decision Tree)
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)
pred_tree = dtree.predict(X_test)
print('\n CONFUSION MATRIX:\n', confusion_matrix(true, pred_tree))
print('\n\n ACCURACY SCORE IS:', accuracy_score(true, pred_tree))
# Out:
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
#  CONFUSION MATRIX:
#  [[10  2]
#  [ 5  8]]
#
#
#  ACCURACY SCORE IS: 0.72

# %%
# Classifier (SVM)
from sklearn.svm import SVC
svm_model = SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
svm_model.fit(X_train, y_train)
pred_svm = svm_model.predict(np.array(X_test))
print('\n CONFUSION MATRIX:\n', confusion_matrix(true, pred_svm))
print('\n\n ACCURACY SCORE IS:', accuracy_score(true, pred_svm))
# Out:
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
#  CONFUSION MATRIX:
#  [[10  2]
#  [ 7  6]]
#
#
#  ACCURACY SCORE IS: 0.64

# %%
# Classifier(K-Nearest Neighbors)
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train,y_train)
pred_knn = knn.predict(X_test)
print('\n\n ACCURACY SCORE IS:', accuracy_score(true, pred_knn))

# BEST VALUE OF K (Will take some time)
error_rate = []
for i in range(1, 40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    pred_i = pred_i.reshape(25, 1)
    error_rate.append(np.mean(pred_i != y_test))

plt.figure(figsize=(10, 6))
plt.plot(range(1, 40), error_rate, color='blue', linestyle='dashed', marker='o',
          markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
plt.show()
# Out:
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
#  ACCURACY SCORE IS: 0.68
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."

# %%
# KNN with best K
knn = KNeighborsClassifier(n_neighbors=13)
knn.fit(X_train, y_train)
pred_knn = knn.predict(X_test)
print('\n CONFUSION MATRIX:\n', confusion_matrix(true, pred_knn))
print('\n\n ACCURACY SCORE IS:', accuracy_score(true, pred_knn))
# Out:
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
#  CONFUSION MATRIX:
#  [[10  2]
#  [ 3 10]]
#
#
#  ACCURACY SCORE IS: 0.8

# %%
# Classifier (Logistic Regression)
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
pred_log = logmodel.predict(X_test)
print('\n CONFUSION MATRIX:\n', confusion_matrix(true, pred_log))
print('\n\n ACCURACY SCORE IS:', accuracy_score(true, pred_log))
# Out:
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
#  CONFUSION MATRIX:
#  [[10  2]
#  [ 7  6]]
#
#
#  ACCURACY SCORE IS: 0.64

# %%
# Classifier (Naive Bayes)
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
nb.fit(X_train,y_train)
pred_naive = nb.predict(X_test)
print('\n CONFUSION MATRIX:\n', confusion_matrix(true, pred_naive))
print('\n\n ACCURACY SCORE IS:', accuracy_score(true, pred_naive), '\n')
# Out:
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\onjad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:573: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
#  CONFUSION MATRIX:
#  [[ 0 12]
#  [ 0 13]]
#
#
#  ACCURACY SCORE IS: 0.52

# %%
print('ACCURACY SCORE OF EACH CLASSIFIER:\n')
print('NEURAL NETWORK:', accuracy_score(true, pred))
print('RANDOM FOREST:', accuracy_score(true, pred_rfc))
print('DECISION TREE:', accuracy_score(true, pred_tree))
print('SVM:', accuracy_score(true, pred_svm))
print('K NEAREST NEIGHBORS:', accuracy_score(true, pred_knn))
print('LOGISTIC REGRESSION:', accuracy_score(true, pred_log))
print('NAIVE BAYES:', accuracy_score(true, pred_naive))
# Out:
# ACCURACY SCORE OF EACH CLASSIFIER:
#
# NEURAL NETWORK: 0.64
# RANDOM FOREST: 0.84
# DECISION TREE: 0.72
# SVM: 0.64
# K NEAREST NEIGHBORS: 0.8
# LOGISTIC REGRESSION: 0.64
# NAIVE BAYES: 0.52
